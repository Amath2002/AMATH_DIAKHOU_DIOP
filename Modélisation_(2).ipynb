# %% [markdown]
# <h1 style="text-align:center;color:#06344ef6;font-size:50px;font-family:bodoni MT;border:solid"> Initiation au machine learning : Projet final </h1>

# %% [markdown]
# <h2 style="text-align:center;color:#06344ef6;font-size:30px;font-family:bodoni MT">  Prédiction des ventes du réseau Oshop </h2>

# %% [markdown]
# <div style="display:flex;text-align:justify">
#
# <ul style="text-align:justify;font-family:bodoni MT;font-size:25px;list-style-type:circle; width:60%">
# <span style="font-weight:bold">Réalisé par: </span>
#     <ul style="text-align:justify;font-family:times;font-size:18px;list-style-type:circle">
#         <li>Mouhamed El M. DIOP</li>
#         <li>Diakhou NDAO</li>
#         <li>Amath SALL</li>
#     </ul>
#     <span style="font-style:italic;color:#06344ef6;font-size:15px">Eléves Ingénieurs des travaux statistiques</span>
# </ul>
#
# <ul style="text-align:justify;font-family:bodoni MT;font-size:23px;list-style-type:none;width:39%">
#  <li style="font-weight:bold">Sous la supervision de:</li>
# <li>Mme Mously DIAW</li>
#   <span style="font-style:italic;color:#06344ef6;font-size:17px"> Senior Machine Learning engineer </span>
# </ul>
#
# </div>

# %% [markdown]
# **<h1 style="color:#06344ef6;text-align:center;font-size:35px;font-family:Bodoni MT"> Modélisation </h1>**

# %%
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import time
import seaborn as sns
from sklearn.metrics import (r2_score,
                             mean_squared_error,
                             mean_absolute_percentage_error,
                             max_error,
                            )

# %%
def get_all_performances(value_train, values_test, metrics):
    test_perfs = []
    train_perfs = []
    metric_names = []
    for metric_func in metrics:
        metric_name = metric_func.__name__
        metric_names.append(metric_name)
        train_perfs.append(metric_func(*value_train))
        test_perfs.append(metric_func(*values_test))
    perfs = {"metric": metric_names, "train": train_perfs, "test": test_perfs,}
    return pd.DataFrame(perfs)

METRICS = [r2_score,
           mean_squared_error,
           mean_absolute_percentage_error,
           max_error,
          ]

# %%
X_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/bases/Feature_Eng_res.csv')

# %%
X_train.head(5)
# Out:
#    date_block_num  shop_id  item_category_id  item_id  item_cnt_month  \
# 0               3        2                37       31             1.0
# 1               3        2                49      464             1.0
# 2               3        2                73      482             1.0
# 3               3        2                73      484             3.0
# 4               3        2                73      485             2.0
#
#    cat_lag_1  item_cnt_month_lag_1  item_cnt_month_lag_2  \
# 0      False                   1.0                   4.0
# 1      False                   0.0                   0.0
# 2      False                   1.0                   1.0
# 3      False                   2.0                   4.0
# 4      False                   0.0                   0.0
#
#    item_cnt_month_lag_3  date_avg_item_cnt_lag_1  ...  \
# 0                   0.0                    1.926  ...
# 1                   0.0                    0.000  ...
# 2                   1.0                    1.926  ...
# 3                   2.0                    1.926  ...
# 4                   0.0                    0.000  ...
#
#    date_category_avg_item_cnt_month_lag_3  \
# 0                                0.000000
# 1                                0.000000
# 2                                2.644898
# 3                                2.644898
# 4                                0.000000
#
#    date_shop_category_avg_item_cnt_month_lag_1  \
# 0                                     1.000000
# 1                                     0.000000
# 2                                     1.285714
# 3                                     1.285714
# 4                                     0.000000
#
#    date_shop_category_avg_item_cnt_month_lag_2  \
# 0                                     1.500000
# 1                                     0.000000
# 2                                     1.666667
# 3                                     1.666667
# 4                                     0.000000
#
#    date_shop_category_avg_item_cnt_month_lag_3  date_avg_item_price_lag_1  \
# 0                                          0.0                      688.5
# 1                                          0.0                      299.0
# 2                                          1.4                     3234.0
# 3                                          1.4                      298.5
# 4                                          0.0                      297.2
#
#    date_avg_item_price_lag_2  date_avg_item_price_lag_3  \
# 0                      667.0                      519.0
# 1                      299.0                      294.8
# 2                     3192.0                     3186.0
# 3                      291.5                      286.2
# 4                     2196.0                     2176.0
#
#    date_shop_avg_item_price_lag_1  date_shop_avg_item_price_lag_2  \
# 0                           698.5                           699.0
# 1                           299.0                           299.0
# 2                          3300.0                          3300.0
# 3                           300.0                           300.0
# 4                           291.8                          2236.0
#
#    date_shop_avg_item_price_lag_3
# 0                           525.0
# 1                           299.0
# 2                          3300.0
# 3                           300.0
# 4                          2232.0
#
# [5 rows x 30 columns]

# %% [markdown]
# # Random Forest

# %%
X_randF = X_train.copy()
# Transformer les var shop_id et item_category_id en numérique pour les inclure dans notre modèle
X_randF[['shop_id','item_category_id']]=X_randF[['shop_id','item_category_id']].astype(object)
X_randF = X_randF.drop(['item_id'],axis=1)

vars = X_randF.select_dtypes(include=['object']).columns
for var in vars:
    tmp = pd.get_dummies(X_randF[var] , prefix=var,drop_first=True)
    X_randF = X_randF.join(tmp)

del tmp
    
X_randF_train = X_randF[X_randF.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_randF_train = X_randF[X_randF.date_block_num < 33]['item_cnt_month']
X_randF_valid = X_randF[X_randF.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_randF_valid = X_randF[X_randF.date_block_num == 33]['item_cnt_month']

X_randF_train = X_randF_train.drop(['shop_id','date_block_num','item_category_id'],axis=1)
X_randF_valid = X_randF_valid.drop(['shop_id','date_block_num','item_category_id'],axis=1)

del X_randF

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Modèle de regression Random Forest
Model_RF = RandomForestRegressor(
        n_estimators=300, #c
        criterion='mse', 
        max_depth=15, #c
        verbose=1, 
        random_state=0 ,
        n_jobs=-1)

Model_RF.fit(X_randF_train, Y_randF_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed: 71.4min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed: 108.7min finished
# RandomForestRegressor(criterion='mse', max_depth=15, n_estimators=300,
#                       n_jobs=-1, random_state=0, verbose=1)

# %%
# Prédiction et Evaluation du modèle
Y_randF_valid_pred = Model_RF.predict(X_randF_valid)
Y_randF_train_pred = Model_RF.predict(X_randF_train)

# Métriques d'evaluation
get_all_performances(value_train=(Y_randF_train, Y_randF_train_pred),
                     values_test=(Y_randF_valid, Y_randF_valid_pred),
                     metrics=METRICS)
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=2)]: Done 300 out of 300 | elapsed:    0.9s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=2)]: Done 300 out of 300 | elapsed:   35.5s finished
#                            metric       train       test
# 0                        r2_score    0.937039   0.872640
# 1              mean_squared_error    3.852808   4.223062
# 2  mean_absolute_percentage_error    0.495027   0.501054
# 3                       max_error  383.628125  84.751184

# %%
del X_randF_train , X_randF_valid , Y_randF_train , Y_randF_valid , Y_randF_valid_pred , Y_randF_train_pred , Model_RF

# %% [markdown]
# ## LIGHTGBM

# %%
import lightgbm as lgb

# %%
data = X_train.copy()
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']

# %%
# %%time
feature_names = X_train.drop(['date_block_num'],axis=1).columns.tolist()

params = {
    'objective': 'mse',
    'metric': 'rmse',
    'num_leaves': 255,
    'learning_rate': 0.005,
    'feature_fraction': 0.75,
    'bagging_fraction': 0.75,
    'bagging_freq': 5,
    'seed': 1,
    'verbose': 1,
    'force_row_wise' : True
}

categorical_feature_names = [ 
                            'shop_id',
                            'item_id',
                            #'date_block_num' # enlever ou pas
                            'item_category_id',
                            'cat_lag_1'
                            
                            ]

lgb_train = lgb.Dataset(X_train[feature_names], Y_train, categorical_feature=None)
lgb_eval  = lgb.Dataset(X_valid[feature_names], Y_valid, categorical_feature=None, reference=lgb_train)

evals_result = {}
gbm = lgb.train(
        params, 
        lgb_train,
        num_boost_round = 4000,
        valid_sets = (lgb_train, lgb_eval), 
        feature_name = feature_names,
        categorical_feature = categorical_feature_names,
        verbose_eval = 100, 
        evals_result = evals_result,
        early_stopping_rounds = 100)
# Out:
# /usr/local/lib/python3.8/dist-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 5.54728	valid_1's rmse: 3.8621
# [200]	training's rmse: 4.30777	valid_1's rmse: 2.84515
# [300]	training's rmse: 3.66466	valid_1's rmse: 2.38425
# [400]	training's rmse: 3.30801	valid_1's rmse: 2.18867
# [500]	training's rmse: 3.09087	valid_1's rmse: 2.12274
# [600]	training's rmse: 2.94016	valid_1's rmse: 2.11153
# Early stopping, best iteration is:
# [590]	training's rmse: 2.95339	valid_1's rmse: 2.1059
# CPU times: user 12min 39s, sys: 3.45 s, total: 12min 43s
# Wall time: 6min 42s

# %%
#X_train.drop(['date_block_num'],axis=1)
y_valid_pred = gbm.predict(X_valid.drop(['date_block_num'],axis=1))
y_train_pred = gbm.predict(X_train.drop(['date_block_num'],axis=1))

# %%
get_all_performances(value_train=(Y_train, y_train_pred),
                     values_test=(Y_valid, y_valid_pred),
                     metrics=METRICS
                    )
# Out:
#                            metric       train       test
# 0                        r2_score    0.857460   0.866187
# 1              mean_squared_error    8.722490   4.437038
# 2  mean_absolute_percentage_error    0.458900   0.539971
# 3                       max_error  910.443698  93.106561

# %%
ax = lgb.plot_importance(gbm, figsize=(12, 8))
plt.show()

# %% [markdown]
# ## optimisation des hyperparamètres

# %%
# optimisation des hyperparametres
####################################### mettre les parametres et le modele
param_grid = {
    # les paramètres],
}

from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(# le modele , param_grid, cv=5, scoring="r2", return_train_score=True, verbose = 2)
grid_search.fit(#train et test)

# les meilleurs hyperparametres
print("Best hyperparameters:", grid_search.best_params_)

# %%
# Prédiction et Evaluation du meilleur modèle
Y_lgm_valid_pred_opt = grid_search.predict(X_valid)
Y_lgm_train_pred_opt = grid_search.predict(X_train)

# Métriques d'evaluation
get_all_performances(value_train=(Y_train, Y_lgm_train_pred_opt),
                     values_test=(Y_valid, Y_lgm_valid_pred_opt),
                     metrics=METRICS)
# Out:
#                            metric        train         test
# 0                        r2_score     0.811834     0.299235
# 1              mean_squared_error    14.945737   165.320026
# 2  mean_absolute_percentage_error     0.571950     0.566688
# 3                       max_error  1219.314325  1988.221791

# %%
del X_train , X_valid , Y_train , Y_valid , gbm

# %% [markdown]
# ## XGBOOST

# %%
from xgboost import XGBRegressor

# %%
data = X_train.copy()
X_XGB = data.copy()
X_XGB[['shop_id','item_category_id']]=X_XGB[['shop_id','item_category_id']].astype(object)
X_XGB = X_XGB.drop(['item_id','cat_lag_1'],axis=1)

vars = X_XGB.select_dtypes(include=['object']).columns
for var in vars:
    tmp = pd.get_dummies(X_XGB[var] , prefix=var,drop_first=True)
    X_XGB = X_XGB.join(tmp)



X_XGB_train = X_XGB[X_XGB.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_XGB_train = X_XGB[X_XGB.date_block_num < 33]['item_cnt_month']
X_XGB_valid = X_XGB[X_XGB.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_XGB_valid = X_XGB[X_XGB.date_block_num == 33]['item_cnt_month']

X_XGB_train = X_XGB_train.drop(['shop_id','date_block_num','item_category_id'],axis=1)
X_XGB_valid = X_XGB_valid.drop(['shop_id','date_block_num','item_category_id'],axis=1)
del tmp , X_XGB
#X_XGB_train

# %%
# %%time
model = XGBRegressor(
    max_depth=10,
    n_estimators=1000,
    min_child_weight=0.5, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.1,
    
#     tree_method='gpu_hist',
    seed=42)

model.fit(
    X_XGB_train, 
    Y_XGB_train, 
    eval_metric="rmse", 
    eval_set=[(X_XGB_train, Y_XGB_train),(X_XGB_valid, Y_XGB_valid)], 
    verbose=True, 
    early_stopping_rounds = 20)
# Out:
# [23:29:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.32973	validation_1-rmse:5.4431
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.78923	validation_1-rmse:5.06481
# [2]	validation_0-rmse:6.29085	validation_1-rmse:4.63873
# [3]	validation_0-rmse:5.82653	validation_1-rmse:4.30921
# [4]	validation_0-rmse:5.44289	validation_1-rmse:4.04749
# [5]	validation_0-rmse:5.06773	validation_1-rmse:3.75451
# [6]	validation_0-rmse:4.72817	validation_1-rmse:3.52155
# [7]	validation_0-rmse:4.43222	validation_1-rmse:3.32628
# [8]	validation_0-rmse:4.15724	validation_1-rmse:3.15685
# [9]	validation_0-rmse:3.93325	validation_1-rmse:2.96088
# [10]	validation_0-rmse:3.73535	validation_1-rmse:2.84997
# [11]	validation_0-rmse:3.53831	validation_1-rmse:2.71028
# [12]	validation_0-rmse:3.35514	validation_1-rmse:2.6078
# [13]	validation_0-rmse:3.18506	validation_1-rmse:2.56526
# [14]	validation_0-rmse:3.05062	validation_1-rmse:2.52729
# [15]	validation_0-rmse:2.92255	validation_1-rmse:2.4678
# [16]	validation_0-rmse:2.81238	validation_1-rmse:2.4206
# [17]	validation_0-rmse:2.7187	validation_1-rmse:2.37022
# [18]	validation_0-rmse:2.63365	validation_1-rmse:2.32806
# [19]	validation_0-rmse:2.54807	validation_1-rmse:2.29183
# [20]	validation_0-rmse:2.47628	validation_1-rmse:2.28085
# [21]	validation_0-rmse:2.40695	validation_1-rmse:2.25307
# [22]	validation_0-rmse:2.35009	validation_1-rmse:2.24546
# [23]	validation_0-rmse:2.29843	validation_1-rmse:2.22363
# [24]	validation_0-rmse:2.25955	validation_1-rmse:2.20964
# [25]	validation_0-rmse:2.22149	validation_1-rmse:2.19477
# [26]	validation_0-rmse:2.18117	validation_1-rmse:2.18122
# [27]	validation_0-rmse:2.14297	validation_1-rmse:2.17913
# [28]	validation_0-rmse:2.11421	validation_1-rmse:2.20219
# [29]	validation_0-rmse:2.08364	validation_1-rmse:2.1966
# [30]	validation_0-rmse:2.05283	validation_1-rmse:2.18322
# [31]	validation_0-rmse:2.02867	validation_1-rmse:2.17635
# [32]	validation_0-rmse:2.0061	validation_1-rmse:2.17058
# [33]	validation_0-rmse:1.99028	validation_1-rmse:2.16992
# [34]	validation_0-rmse:1.97238	validation_1-rmse:2.16334
# [35]	validation_0-rmse:1.95433	validation_1-rmse:2.15828
# [36]	validation_0-rmse:1.94184	validation_1-rmse:2.15358
# [37]	validation_0-rmse:1.92445	validation_1-rmse:2.14511
# [38]	validation_0-rmse:1.91236	validation_1-rmse:2.13966
# [39]	validation_0-rmse:1.89489	validation_1-rmse:2.13379
# [40]	validation_0-rmse:1.88092	validation_1-rmse:2.12952
# [41]	validation_0-rmse:1.87018	validation_1-rmse:2.12917
# [42]	validation_0-rmse:1.86382	validation_1-rmse:2.12817
# [43]	validation_0-rmse:1.85154	validation_1-rmse:2.12504
# [44]	validation_0-rmse:1.84188	validation_1-rmse:2.11998
# [45]	validation_0-rmse:1.83045	validation_1-rmse:2.15088
# [46]	validation_0-rmse:1.82303	validation_1-rmse:2.14809
# [47]	validation_0-rmse:1.81532	validation_1-rmse:2.14583
# [48]	validation_0-rmse:1.80918	validation_1-rmse:2.14412
# [49]	validation_0-rmse:1.80207	validation_1-rmse:2.14447
# [50]	validation_0-rmse:1.79446	validation_1-rmse:2.14081
# [51]	validation_0-rmse:1.78598	validation_1-rmse:2.15337
# [52]	validation_0-rmse:1.77997	validation_1-rmse:2.1521
# [53]	validation_0-rmse:1.77562	validation_1-rmse:2.15239
# [54]	validation_0-rmse:1.77067	validation_1-rmse:2.14494
# [55]	validation_0-rmse:1.76468	validation_1-rmse:2.15703
# [56]	validation_0-rmse:1.76016	validation_1-rmse:2.1552
# [57]	validation_0-rmse:1.75554	validation_1-rmse:2.1567
# [58]	validation_0-rmse:1.75133	validation_1-rmse:2.15289
# [59]	validation_0-rmse:1.74739	validation_1-rmse:2.15238
# [60]	validation_0-rmse:1.74129	validation_1-rmse:2.16244
# [61]	validation_0-rmse:1.73788	validation_1-rmse:2.16458
# [62]	validation_0-rmse:1.73577	validation_1-rmse:2.16358
# [63]	validation_0-rmse:1.73319	validation_1-rmse:2.16437
# [64]	validation_0-rmse:1.7309	validation_1-rmse:2.1657
# Stopping. Best iteration:
# [44]	validation_0-rmse:1.84188	validation_1-rmse:2.11998
#
# CPU times: user 21min 40s, sys: 6.06 s, total: 21min 46s
# Wall time: 22min 5s
# XGBRegressor(colsample_bytree=0.8, eta=0.1, max_depth=10, min_child_weight=0.5,
#              n_estimators=1000, seed=42, subsample=0.8)

# %%
# %%time
y_valid_pred = model.predict(X_XGB_valid)
y_train_pred = model.predict(X_XGB_train)

get_all_performances(value_train=(Y_XGB_train, y_train_pred),
                     values_test=(Y_XGB_valid, y_valid_pred),
                     metrics=METRICS
                    )
# Out:
# CPU times: user 7.5 s, sys: 973 ms, total: 8.47 s
# Wall time: 8.52 s
#                            metric       train        test
# 0                        r2_score    0.944550    0.864459
# 1              mean_squared_error    3.393139    4.494334
# 2  mean_absolute_percentage_error    0.493673    0.510470
# 3                       max_error  257.410217  121.098618

# %% [markdown]
# ## Optimisation des hyperparamètres

# %%
# optimisation des hyperparametres
param_grid = {
    'max_depth' : [10, 15],
    'n_estimators' : [1000, 1200],
}

from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(XGBRegressor(seed = 42), param_grid, cv=4, scoring="r2", return_train_score=True, verbose = 2)
grid_search.fit(X_XGB_train, Y_XGB_train, 
                eval_set=[(X_XGB_train, Y_XGB_train),(X_XGB_valid, Y_XGB_valid)], 
                verbose=True, 
                early_stopping_rounds = 20)
# Out:
# Fitting 4 folds for each of 4 candidates, totalling 16 fits
# [16:34:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.33049	validation_1-rmse:5.4531
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.77678	validation_1-rmse:4.99593
# [2]	validation_0-rmse:6.27272	validation_1-rmse:4.61625
# [3]	validation_0-rmse:5.81531	validation_1-rmse:4.24717
# [4]	validation_0-rmse:5.41059	validation_1-rmse:3.91891
# [5]	validation_0-rmse:5.04838	validation_1-rmse:3.69097
# [6]	validation_0-rmse:4.71972	validation_1-rmse:3.45241
# [7]	validation_0-rmse:4.42399	validation_1-rmse:3.23615
# [8]	validation_0-rmse:4.16189	validation_1-rmse:3.05797
# [9]	validation_0-rmse:3.92919	validation_1-rmse:2.90764
# [10]	validation_0-rmse:3.72533	validation_1-rmse:2.7768
# [11]	validation_0-rmse:3.54295	validation_1-rmse:2.6695
# [12]	validation_0-rmse:3.37624	validation_1-rmse:2.56682
# [13]	validation_0-rmse:3.23502	validation_1-rmse:2.48182
# [14]	validation_0-rmse:3.10517	validation_1-rmse:2.42151
# [15]	validation_0-rmse:2.99517	validation_1-rmse:2.36216
# [16]	validation_0-rmse:2.90005	validation_1-rmse:2.32011
# [17]	validation_0-rmse:2.80824	validation_1-rmse:2.28333
# [18]	validation_0-rmse:2.73008	validation_1-rmse:2.26555
# [19]	validation_0-rmse:2.66046	validation_1-rmse:2.25474
# [20]	validation_0-rmse:2.59681	validation_1-rmse:2.22296
# [21]	validation_0-rmse:2.53917	validation_1-rmse:2.19825
# [22]	validation_0-rmse:2.49026	validation_1-rmse:2.17463
# [23]	validation_0-rmse:2.44829	validation_1-rmse:2.15794
# [24]	validation_0-rmse:2.41231	validation_1-rmse:2.14155
# [25]	validation_0-rmse:2.37793	validation_1-rmse:2.14399
# [26]	validation_0-rmse:2.34854	validation_1-rmse:2.14082
# [27]	validation_0-rmse:2.32475	validation_1-rmse:2.13228
# [28]	validation_0-rmse:2.30158	validation_1-rmse:2.13664
# [29]	validation_0-rmse:2.2818	validation_1-rmse:2.14065
# [30]	validation_0-rmse:2.26496	validation_1-rmse:2.13539
# [31]	validation_0-rmse:2.25033	validation_1-rmse:2.14229
# [32]	validation_0-rmse:2.23645	validation_1-rmse:2.1507
# [33]	validation_0-rmse:2.22428	validation_1-rmse:2.15733
# [34]	validation_0-rmse:2.2131	validation_1-rmse:2.15121
# [35]	validation_0-rmse:2.20381	validation_1-rmse:2.14624
# [36]	validation_0-rmse:2.19547	validation_1-rmse:2.15587
# [37]	validation_0-rmse:2.1882	validation_1-rmse:2.1498
# [38]	validation_0-rmse:2.18098	validation_1-rmse:2.14792
# [39]	validation_0-rmse:2.1752	validation_1-rmse:2.14598
# [40]	validation_0-rmse:2.1691	validation_1-rmse:2.14376
# [41]	validation_0-rmse:2.1643	validation_1-rmse:2.14234
# [42]	validation_0-rmse:2.15979	validation_1-rmse:2.14045
# [43]	validation_0-rmse:2.15593	validation_1-rmse:2.13944
# [44]	validation_0-rmse:2.15206	validation_1-rmse:2.13911
# [45]	validation_0-rmse:2.14827	validation_1-rmse:2.13599
# [46]	validation_0-rmse:2.14517	validation_1-rmse:2.13393
# [47]	validation_0-rmse:2.14236	validation_1-rmse:2.13611
# Stopping. Best iteration:
# [27]	validation_0-rmse:2.32475	validation_1-rmse:2.13228
#
# [CV] END ....................max_depth=10, n_estimators=1000; total time=10.7min
# [16:45:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.32957	validation_1-rmse:5.4932
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.7722	validation_1-rmse:4.98109
# [2]	validation_0-rmse:6.27347	validation_1-rmse:4.65496
# [3]	validation_0-rmse:5.82683	validation_1-rmse:4.35566
# [4]	validation_0-rmse:5.43198	validation_1-rmse:4.08684
# [5]	validation_0-rmse:5.08828	validation_1-rmse:3.79592
# [6]	validation_0-rmse:4.7614	validation_1-rmse:3.69669
# [7]	validation_0-rmse:4.48892	validation_1-rmse:3.49427
# [8]	validation_0-rmse:4.24003	validation_1-rmse:3.33907
# [9]	validation_0-rmse:4.02501	validation_1-rmse:3.28822
# [10]	validation_0-rmse:3.84051	validation_1-rmse:3.09639
# [11]	validation_0-rmse:3.67034	validation_1-rmse:2.93526
# [12]	validation_0-rmse:3.52671	validation_1-rmse:2.8368
# [13]	validation_0-rmse:3.39681	validation_1-rmse:2.76381
# [14]	validation_0-rmse:3.28409	validation_1-rmse:2.7214
# [15]	validation_0-rmse:3.18854	validation_1-rmse:2.65394
# [16]	validation_0-rmse:3.10468	validation_1-rmse:2.60504
# [17]	validation_0-rmse:3.02868	validation_1-rmse:2.54736
# [18]	validation_0-rmse:2.95938	validation_1-rmse:2.50231
# [19]	validation_0-rmse:2.89123	validation_1-rmse:2.46315
# [20]	validation_0-rmse:2.84125	validation_1-rmse:2.42611
# [21]	validation_0-rmse:2.79598	validation_1-rmse:2.39252
# [22]	validation_0-rmse:2.75816	validation_1-rmse:2.36263
# [23]	validation_0-rmse:2.7245	validation_1-rmse:2.34376
# [24]	validation_0-rmse:2.69184	validation_1-rmse:2.31545
# [25]	validation_0-rmse:2.66512	validation_1-rmse:2.298
# [26]	validation_0-rmse:2.64139	validation_1-rmse:2.29361
# [27]	validation_0-rmse:2.62029	validation_1-rmse:2.29143
# [28]	validation_0-rmse:2.60094	validation_1-rmse:2.27828
# [29]	validation_0-rmse:2.58484	validation_1-rmse:2.27613
# [30]	validation_0-rmse:2.57021	validation_1-rmse:2.26534
# [31]	validation_0-rmse:2.55835	validation_1-rmse:2.26606
# [32]	validation_0-rmse:2.54811	validation_1-rmse:2.25963
# [33]	validation_0-rmse:2.53774	validation_1-rmse:2.26772
# [34]	validation_0-rmse:2.52946	validation_1-rmse:2.27279
# [35]	validation_0-rmse:2.52234	validation_1-rmse:2.27799
# [36]	validation_0-rmse:2.51015	validation_1-rmse:2.27456
# [37]	validation_0-rmse:2.50466	validation_1-rmse:2.26932
# [38]	validation_0-rmse:2.49895	validation_1-rmse:2.27754
# [39]	validation_0-rmse:2.49452	validation_1-rmse:2.28408
# [40]	validation_0-rmse:2.48929	validation_1-rmse:2.2801
# [41]	validation_0-rmse:2.48535	validation_1-rmse:2.28378
# [42]	validation_0-rmse:2.48024	validation_1-rmse:2.27942
# [43]	validation_0-rmse:2.47478	validation_1-rmse:2.27846
# [44]	validation_0-rmse:2.46814	validation_1-rmse:2.27648
# [45]	validation_0-rmse:2.46482	validation_1-rmse:2.27419
# [46]	validation_0-rmse:2.45885	validation_1-rmse:2.27395
# [47]	validation_0-rmse:2.45656	validation_1-rmse:2.27695
# [48]	validation_0-rmse:2.45245	validation_1-rmse:2.27472
# [49]	validation_0-rmse:2.45077	validation_1-rmse:2.27413
# [50]	validation_0-rmse:2.44988	validation_1-rmse:2.27333
# [51]	validation_0-rmse:2.44755	validation_1-rmse:2.27262
# [52]	validation_0-rmse:2.44599	validation_1-rmse:2.27171
# Stopping. Best iteration:
# [32]	validation_0-rmse:2.54811	validation_1-rmse:2.25963
#
# [CV] END ....................max_depth=10, n_estimators=1000; total time=11.0min
# [16:56:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.3421	validation_1-rmse:5.49083
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.77997	validation_1-rmse:5.05974
# [2]	validation_0-rmse:6.26694	validation_1-rmse:4.70622
# [3]	validation_0-rmse:5.81297	validation_1-rmse:4.37536
# [4]	validation_0-rmse:5.41922	validation_1-rmse:4.08558
# [5]	validation_0-rmse:5.06684	validation_1-rmse:3.83659
# [6]	validation_0-rmse:4.73495	validation_1-rmse:3.58091
# [7]	validation_0-rmse:4.44916	validation_1-rmse:3.36712
# [8]	validation_0-rmse:4.19433	validation_1-rmse:3.16788
# [9]	validation_0-rmse:3.96163	validation_1-rmse:3.01296
# [10]	validation_0-rmse:3.76804	validation_1-rmse:2.88529
# [11]	validation_0-rmse:3.58761	validation_1-rmse:2.75142
# [12]	validation_0-rmse:3.43254	validation_1-rmse:2.63222
# [13]	validation_0-rmse:3.29564	validation_1-rmse:2.56284
# [14]	validation_0-rmse:3.17317	validation_1-rmse:2.49157
# [15]	validation_0-rmse:3.06654	validation_1-rmse:2.43682
# [16]	validation_0-rmse:2.97493	validation_1-rmse:2.39062
# [17]	validation_0-rmse:2.89588	validation_1-rmse:2.35083
# [18]	validation_0-rmse:2.82657	validation_1-rmse:2.31157
# [19]	validation_0-rmse:2.76666	validation_1-rmse:2.27822
# [20]	validation_0-rmse:2.71299	validation_1-rmse:2.24056
# [21]	validation_0-rmse:2.66648	validation_1-rmse:2.21066
# [22]	validation_0-rmse:2.62501	validation_1-rmse:2.1913
# [23]	validation_0-rmse:2.59014	validation_1-rmse:2.1659
# [24]	validation_0-rmse:2.55785	validation_1-rmse:2.14871
# [25]	validation_0-rmse:2.53228	validation_1-rmse:2.13199
# [26]	validation_0-rmse:2.50817	validation_1-rmse:2.12028
# [27]	validation_0-rmse:2.48942	validation_1-rmse:2.11003
# [28]	validation_0-rmse:2.47163	validation_1-rmse:2.09567
# [29]	validation_0-rmse:2.45637	validation_1-rmse:2.08507
# [30]	validation_0-rmse:2.4434	validation_1-rmse:2.07889
# [31]	validation_0-rmse:2.4313	validation_1-rmse:2.06894
# [32]	validation_0-rmse:2.42168	validation_1-rmse:2.06034
# [33]	validation_0-rmse:2.41252	validation_1-rmse:2.04967
# [34]	validation_0-rmse:2.40554	validation_1-rmse:2.04236
# [35]	validation_0-rmse:2.3988	validation_1-rmse:2.03753
# [36]	validation_0-rmse:2.39321	validation_1-rmse:2.03325
# [37]	validation_0-rmse:2.38813	validation_1-rmse:2.03082
# [38]	validation_0-rmse:2.38318	validation_1-rmse:2.02111
# [39]	validation_0-rmse:2.37967	validation_1-rmse:2.01869
# [40]	validation_0-rmse:2.37739	validation_1-rmse:2.01434
# [41]	validation_0-rmse:2.37301	validation_1-rmse:2.00996
# [42]	validation_0-rmse:2.36874	validation_1-rmse:2.00718
# [43]	validation_0-rmse:2.36639	validation_1-rmse:2.00367
# [44]	validation_0-rmse:2.36269	validation_1-rmse:1.99844
# [45]	validation_0-rmse:2.35926	validation_1-rmse:1.99604
# [46]	validation_0-rmse:2.35684	validation_1-rmse:1.99289
# [47]	validation_0-rmse:2.35438	validation_1-rmse:1.99125
# [48]	validation_0-rmse:2.35176	validation_1-rmse:1.99116
# [49]	validation_0-rmse:2.35055	validation_1-rmse:1.99045
# [50]	validation_0-rmse:2.34844	validation_1-rmse:1.99016
# [51]	validation_0-rmse:2.34698	validation_1-rmse:1.99073
# [52]	validation_0-rmse:2.34707	validation_1-rmse:1.99009
# [53]	validation_0-rmse:2.34612	validation_1-rmse:1.9869
# [54]	validation_0-rmse:2.34424	validation_1-rmse:1.98502
# [55]	validation_0-rmse:2.34302	validation_1-rmse:1.98364
# [56]	validation_0-rmse:2.34089	validation_1-rmse:1.98338
# [57]	validation_0-rmse:2.33974	validation_1-rmse:1.98172
# [58]	validation_0-rmse:2.3392	validation_1-rmse:1.98081
# [59]	validation_0-rmse:2.33905	validation_1-rmse:1.98144
# [60]	validation_0-rmse:2.33777	validation_1-rmse:1.98204
# [61]	validation_0-rmse:2.33681	validation_1-rmse:1.98209
# [62]	validation_0-rmse:2.33631	validation_1-rmse:1.98158
# [63]	validation_0-rmse:2.33554	validation_1-rmse:1.98151
# [64]	validation_0-rmse:2.3341	validation_1-rmse:1.98084
# [65]	validation_0-rmse:2.33361	validation_1-rmse:1.98073
# [66]	validation_0-rmse:2.33298	validation_1-rmse:1.98067
# [67]	validation_0-rmse:2.33236	validation_1-rmse:1.98113
# [68]	validation_0-rmse:2.33035	validation_1-rmse:1.97954
# [69]	validation_0-rmse:2.33005	validation_1-rmse:1.97874
# [70]	validation_0-rmse:2.32952	validation_1-rmse:1.97929
# [71]	validation_0-rmse:2.32742	validation_1-rmse:1.97841
# [72]	validation_0-rmse:2.32467	validation_1-rmse:1.97878
# [73]	validation_0-rmse:2.32441	validation_1-rmse:1.97858
# [74]	validation_0-rmse:2.32207	validation_1-rmse:1.98172
# [75]	validation_0-rmse:2.3213	validation_1-rmse:1.98119
# [76]	validation_0-rmse:2.31997	validation_1-rmse:1.98122
# [77]	validation_0-rmse:2.31879	validation_1-rmse:1.98179
# [78]	validation_0-rmse:2.3173	validation_1-rmse:1.98122
# [79]	validation_0-rmse:2.31402	validation_1-rmse:1.97836
# [80]	validation_0-rmse:2.31344	validation_1-rmse:1.97854
# [81]	validation_0-rmse:2.31146	validation_1-rmse:1.97832
# [82]	validation_0-rmse:2.30913	validation_1-rmse:1.97958
# [83]	validation_0-rmse:2.30674	validation_1-rmse:1.97884
# [84]	validation_0-rmse:2.30645	validation_1-rmse:1.98133
# [85]	validation_0-rmse:2.3059	validation_1-rmse:1.98088
# [86]	validation_0-rmse:2.30406	validation_1-rmse:1.97955
# [87]	validation_0-rmse:2.30328	validation_1-rmse:1.98233
# [88]	validation_0-rmse:2.3027	validation_1-rmse:1.98113
# [89]	validation_0-rmse:2.30111	validation_1-rmse:1.97913
# [90]	validation_0-rmse:2.30059	validation_1-rmse:1.97879
# [91]	validation_0-rmse:2.2988	validation_1-rmse:1.97838
# [92]	validation_0-rmse:2.29717	validation_1-rmse:1.97813
# [93]	validation_0-rmse:2.29682	validation_1-rmse:1.97815
# [94]	validation_0-rmse:2.29647	validation_1-rmse:1.97807
# [95]	validation_0-rmse:2.29455	validation_1-rmse:1.97803
# [96]	validation_0-rmse:2.29356	validation_1-rmse:1.97863
# [97]	validation_0-rmse:2.29243	validation_1-rmse:1.97793
# [98]	validation_0-rmse:2.29143	validation_1-rmse:1.9776
# [99]	validation_0-rmse:2.29104	validation_1-rmse:1.97726
# [100]	validation_0-rmse:2.29022	validation_1-rmse:1.98122
# [101]	validation_0-rmse:2.28834	validation_1-rmse:1.98104
# [102]	validation_0-rmse:2.2868	validation_1-rmse:1.98083
# [103]	validation_0-rmse:2.28608	validation_1-rmse:1.98068
# [104]	validation_0-rmse:2.28471	validation_1-rmse:1.98082
# [105]	validation_0-rmse:2.28407	validation_1-rmse:1.98123
# [106]	validation_0-rmse:2.28354	validation_1-rmse:1.98239
# [107]	validation_0-rmse:2.28217	validation_1-rmse:1.98073
# [108]	validation_0-rmse:2.28145	validation_1-rmse:1.98028
# [109]	validation_0-rmse:2.2807	validation_1-rmse:1.98101
# [110]	validation_0-rmse:2.27961	validation_1-rmse:1.98123
# [111]	validation_0-rmse:2.27837	validation_1-rmse:1.9811
# [112]	validation_0-rmse:2.27779	validation_1-rmse:1.98134
# [113]	validation_0-rmse:2.27757	validation_1-rmse:1.98096
# [114]	validation_0-rmse:2.27645	validation_1-rmse:1.98127
# [115]	validation_0-rmse:2.27589	validation_1-rmse:1.98105
# [116]	validation_0-rmse:2.27486	validation_1-rmse:1.98087
# [117]	validation_0-rmse:2.2736	validation_1-rmse:1.98049
# [118]	validation_0-rmse:2.27339	validation_1-rmse:1.98038
# [119]	validation_0-rmse:2.27248	validation_1-rmse:1.98025
# Stopping. Best iteration:
# [99]	validation_0-rmse:2.29104	validation_1-rmse:1.97726
#
# [CV] END ....................max_depth=10, n_estimators=1000; total time=25.7min
# [17:22:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.31935	validation_1-rmse:5.40943
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.76053	validation_1-rmse:4.90505
# [2]	validation_0-rmse:6.26989	validation_1-rmse:4.50123
# [3]	validation_0-rmse:5.82531	validation_1-rmse:4.19954
# [4]	validation_0-rmse:5.43961	validation_1-rmse:3.87177
# [5]	validation_0-rmse:5.08638	validation_1-rmse:3.65085
# [6]	validation_0-rmse:4.77517	validation_1-rmse:3.43039
# [7]	validation_0-rmse:4.51069	validation_1-rmse:3.2333
# [8]	validation_0-rmse:4.28237	validation_1-rmse:3.07079
# [9]	validation_0-rmse:4.08188	validation_1-rmse:2.95399
# [10]	validation_0-rmse:3.89612	validation_1-rmse:2.80636
# [11]	validation_0-rmse:3.7397	validation_1-rmse:2.74282
# [12]	validation_0-rmse:3.60695	validation_1-rmse:2.7413
# [13]	validation_0-rmse:3.49043	validation_1-rmse:2.69663
# [14]	validation_0-rmse:3.39017	validation_1-rmse:2.69048
# [15]	validation_0-rmse:3.31064	validation_1-rmse:2.70797
# [16]	validation_0-rmse:3.24311	validation_1-rmse:2.73536
# [17]	validation_0-rmse:3.18959	validation_1-rmse:2.77071
# [18]	validation_0-rmse:3.14293	validation_1-rmse:2.80595
# [19]	validation_0-rmse:3.10155	validation_1-rmse:2.84787
# [20]	validation_0-rmse:3.06977	validation_1-rmse:2.89693
# [21]	validation_0-rmse:3.03813	validation_1-rmse:2.94677
# [22]	validation_0-rmse:3.01352	validation_1-rmse:2.99404
# [23]	validation_0-rmse:2.99518	validation_1-rmse:3.03812
# [24]	validation_0-rmse:2.97712	validation_1-rmse:3.08168
# [25]	validation_0-rmse:2.96383	validation_1-rmse:3.12328
# [26]	validation_0-rmse:2.94959	validation_1-rmse:3.13122
# [27]	validation_0-rmse:2.93782	validation_1-rmse:3.17919
# [28]	validation_0-rmse:2.93155	validation_1-rmse:3.21851
# [29]	validation_0-rmse:2.92191	validation_1-rmse:3.21934
# [30]	validation_0-rmse:2.91781	validation_1-rmse:3.25805
# [31]	validation_0-rmse:2.91206	validation_1-rmse:3.28982
# [32]	validation_0-rmse:2.90649	validation_1-rmse:3.32079
# [33]	validation_0-rmse:2.90396	validation_1-rmse:3.35089
# [34]	validation_0-rmse:2.89857	validation_1-rmse:3.35306
# Stopping. Best iteration:
# [14]	validation_0-rmse:3.39017	validation_1-rmse:2.69048
#
# [CV] END ....................max_depth=10, n_estimators=1000; total time= 7.9min
# [17:30:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.33049	validation_1-rmse:5.4531
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.77678	validation_1-rmse:4.99593
# [2]	validation_0-rmse:6.27272	validation_1-rmse:4.61625
# [3]	validation_0-rmse:5.81531	validation_1-rmse:4.24717
# [4]	validation_0-rmse:5.41059	validation_1-rmse:3.91891
# [5]	validation_0-rmse:5.04838	validation_1-rmse:3.69097
# [6]	validation_0-rmse:4.71972	validation_1-rmse:3.45241
# [7]	validation_0-rmse:4.42399	validation_1-rmse:3.23615
# [8]	validation_0-rmse:4.16189	validation_1-rmse:3.05797
# [9]	validation_0-rmse:3.92919	validation_1-rmse:2.90764
# [10]	validation_0-rmse:3.72533	validation_1-rmse:2.7768
# [11]	validation_0-rmse:3.54295	validation_1-rmse:2.6695
# [12]	validation_0-rmse:3.37624	validation_1-rmse:2.56682
# [13]	validation_0-rmse:3.23502	validation_1-rmse:2.48182
# [14]	validation_0-rmse:3.10517	validation_1-rmse:2.42151
# [15]	validation_0-rmse:2.99517	validation_1-rmse:2.36216
# [16]	validation_0-rmse:2.90005	validation_1-rmse:2.32011
# [17]	validation_0-rmse:2.80824	validation_1-rmse:2.28333
# [18]	validation_0-rmse:2.73008	validation_1-rmse:2.26555
# [19]	validation_0-rmse:2.66046	validation_1-rmse:2.25474
# [20]	validation_0-rmse:2.59681	validation_1-rmse:2.22296
# [21]	validation_0-rmse:2.53917	validation_1-rmse:2.19825
# [22]	validation_0-rmse:2.49026	validation_1-rmse:2.17463
# [23]	validation_0-rmse:2.44829	validation_1-rmse:2.15794
# [24]	validation_0-rmse:2.41231	validation_1-rmse:2.14155
# [25]	validation_0-rmse:2.37793	validation_1-rmse:2.14399
# [26]	validation_0-rmse:2.34854	validation_1-rmse:2.14082
# [27]	validation_0-rmse:2.32475	validation_1-rmse:2.13228
# [28]	validation_0-rmse:2.30158	validation_1-rmse:2.13664
# [29]	validation_0-rmse:2.2818	validation_1-rmse:2.14065
# [30]	validation_0-rmse:2.26496	validation_1-rmse:2.13539
# [31]	validation_0-rmse:2.25033	validation_1-rmse:2.14229
# [32]	validation_0-rmse:2.23645	validation_1-rmse:2.1507
# [33]	validation_0-rmse:2.22428	validation_1-rmse:2.15733
# [34]	validation_0-rmse:2.2131	validation_1-rmse:2.15121
# [35]	validation_0-rmse:2.20381	validation_1-rmse:2.14624
# [36]	validation_0-rmse:2.19547	validation_1-rmse:2.15587
# [37]	validation_0-rmse:2.1882	validation_1-rmse:2.1498
# [38]	validation_0-rmse:2.18098	validation_1-rmse:2.14792
# [39]	validation_0-rmse:2.1752	validation_1-rmse:2.14598
# [40]	validation_0-rmse:2.1691	validation_1-rmse:2.14376
# [41]	validation_0-rmse:2.1643	validation_1-rmse:2.14234
# [42]	validation_0-rmse:2.15979	validation_1-rmse:2.14045
# [43]	validation_0-rmse:2.15593	validation_1-rmse:2.13944
# [44]	validation_0-rmse:2.15206	validation_1-rmse:2.13911
# [45]	validation_0-rmse:2.14827	validation_1-rmse:2.13599
# [46]	validation_0-rmse:2.14517	validation_1-rmse:2.13393
# [47]	validation_0-rmse:2.14236	validation_1-rmse:2.13611
# Stopping. Best iteration:
# [27]	validation_0-rmse:2.32475	validation_1-rmse:2.13228
#
# [CV] END ....................max_depth=10, n_estimators=1200; total time=10.6min
# [17:40:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.32957	validation_1-rmse:5.4932
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.7722	validation_1-rmse:4.98109
# [2]	validation_0-rmse:6.27347	validation_1-rmse:4.65496
# [3]	validation_0-rmse:5.82683	validation_1-rmse:4.35566
# [4]	validation_0-rmse:5.43198	validation_1-rmse:4.08684
# [5]	validation_0-rmse:5.08828	validation_1-rmse:3.79592
# [6]	validation_0-rmse:4.7614	validation_1-rmse:3.69669
# [7]	validation_0-rmse:4.48892	validation_1-rmse:3.49427
# [8]	validation_0-rmse:4.24003	validation_1-rmse:3.33907
# [9]	validation_0-rmse:4.02501	validation_1-rmse:3.28822
# [10]	validation_0-rmse:3.84051	validation_1-rmse:3.09639
# [11]	validation_0-rmse:3.67034	validation_1-rmse:2.93526
# [12]	validation_0-rmse:3.52671	validation_1-rmse:2.8368
# [13]	validation_0-rmse:3.39681	validation_1-rmse:2.76381
# [14]	validation_0-rmse:3.28409	validation_1-rmse:2.7214
# [15]	validation_0-rmse:3.18854	validation_1-rmse:2.65394
# [16]	validation_0-rmse:3.10468	validation_1-rmse:2.60504
# [17]	validation_0-rmse:3.02868	validation_1-rmse:2.54736
# [18]	validation_0-rmse:2.95938	validation_1-rmse:2.50231
# [19]	validation_0-rmse:2.89123	validation_1-rmse:2.46315
# [20]	validation_0-rmse:2.84125	validation_1-rmse:2.42611
# [21]	validation_0-rmse:2.79598	validation_1-rmse:2.39252
# [22]	validation_0-rmse:2.75816	validation_1-rmse:2.36263
# [23]	validation_0-rmse:2.7245	validation_1-rmse:2.34376
# [24]	validation_0-rmse:2.69184	validation_1-rmse:2.31545
# [25]	validation_0-rmse:2.66512	validation_1-rmse:2.298
# [26]	validation_0-rmse:2.64139	validation_1-rmse:2.29361
# [27]	validation_0-rmse:2.62029	validation_1-rmse:2.29143
# [28]	validation_0-rmse:2.60094	validation_1-rmse:2.27828
# [29]	validation_0-rmse:2.58484	validation_1-rmse:2.27613
# [30]	validation_0-rmse:2.57021	validation_1-rmse:2.26534
# [31]	validation_0-rmse:2.55835	validation_1-rmse:2.26606
# [32]	validation_0-rmse:2.54811	validation_1-rmse:2.25963
# [33]	validation_0-rmse:2.53774	validation_1-rmse:2.26772
# [34]	validation_0-rmse:2.52946	validation_1-rmse:2.27279
# [35]	validation_0-rmse:2.52234	validation_1-rmse:2.27799
# [36]	validation_0-rmse:2.51015	validation_1-rmse:2.27456
# [37]	validation_0-rmse:2.50466	validation_1-rmse:2.26932
# [38]	validation_0-rmse:2.49895	validation_1-rmse:2.27754
# [39]	validation_0-rmse:2.49452	validation_1-rmse:2.28408
# [40]	validation_0-rmse:2.48929	validation_1-rmse:2.2801
# [41]	validation_0-rmse:2.48535	validation_1-rmse:2.28378
# [42]	validation_0-rmse:2.48024	validation_1-rmse:2.27942
# [43]	validation_0-rmse:2.47478	validation_1-rmse:2.27846
# [44]	validation_0-rmse:2.46814	validation_1-rmse:2.27648
# [45]	validation_0-rmse:2.46482	validation_1-rmse:2.27419
# [46]	validation_0-rmse:2.45885	validation_1-rmse:2.27395
# [47]	validation_0-rmse:2.45656	validation_1-rmse:2.27695
# [48]	validation_0-rmse:2.45245	validation_1-rmse:2.27472
# [49]	validation_0-rmse:2.45077	validation_1-rmse:2.27413
# [50]	validation_0-rmse:2.44988	validation_1-rmse:2.27333
# [51]	validation_0-rmse:2.44755	validation_1-rmse:2.27262
# [52]	validation_0-rmse:2.44599	validation_1-rmse:2.27171
# Stopping. Best iteration:
# [32]	validation_0-rmse:2.54811	validation_1-rmse:2.25963
#
# [CV] END ....................max_depth=10, n_estimators=1200; total time=11.6min
# [17:52:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.3421	validation_1-rmse:5.49083
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.77997	validation_1-rmse:5.05974
# [2]	validation_0-rmse:6.26694	validation_1-rmse:4.70622
# [3]	validation_0-rmse:5.81297	validation_1-rmse:4.37536
# [4]	validation_0-rmse:5.41922	validation_1-rmse:4.08558
# [5]	validation_0-rmse:5.06684	validation_1-rmse:3.83659
# [6]	validation_0-rmse:4.73495	validation_1-rmse:3.58091
# [7]	validation_0-rmse:4.44916	validation_1-rmse:3.36712
# [8]	validation_0-rmse:4.19433	validation_1-rmse:3.16788
# [9]	validation_0-rmse:3.96163	validation_1-rmse:3.01296
# [10]	validation_0-rmse:3.76804	validation_1-rmse:2.88529
# [11]	validation_0-rmse:3.58761	validation_1-rmse:2.75142
# [12]	validation_0-rmse:3.43254	validation_1-rmse:2.63222
# [13]	validation_0-rmse:3.29564	validation_1-rmse:2.56284
# [14]	validation_0-rmse:3.17317	validation_1-rmse:2.49157
# [15]	validation_0-rmse:3.06654	validation_1-rmse:2.43682
# [16]	validation_0-rmse:2.97493	validation_1-rmse:2.39062
# [17]	validation_0-rmse:2.89588	validation_1-rmse:2.35083
# [18]	validation_0-rmse:2.82657	validation_1-rmse:2.31157
# [19]	validation_0-rmse:2.76666	validation_1-rmse:2.27822
# [20]	validation_0-rmse:2.71299	validation_1-rmse:2.24056
# [21]	validation_0-rmse:2.66648	validation_1-rmse:2.21066
# [22]	validation_0-rmse:2.62501	validation_1-rmse:2.1913
# [23]	validation_0-rmse:2.59014	validation_1-rmse:2.1659
# [24]	validation_0-rmse:2.55785	validation_1-rmse:2.14871
# [25]	validation_0-rmse:2.53228	validation_1-rmse:2.13199
# [26]	validation_0-rmse:2.50817	validation_1-rmse:2.12028
# [27]	validation_0-rmse:2.48942	validation_1-rmse:2.11003
# [28]	validation_0-rmse:2.47163	validation_1-rmse:2.09567
# [29]	validation_0-rmse:2.45637	validation_1-rmse:2.08507
# [30]	validation_0-rmse:2.4434	validation_1-rmse:2.07889
# [31]	validation_0-rmse:2.4313	validation_1-rmse:2.06894
# [32]	validation_0-rmse:2.42168	validation_1-rmse:2.06034
# [33]	validation_0-rmse:2.41252	validation_1-rmse:2.04967
# [34]	validation_0-rmse:2.40554	validation_1-rmse:2.04236
# [35]	validation_0-rmse:2.3988	validation_1-rmse:2.03753
# [36]	validation_0-rmse:2.39321	validation_1-rmse:2.03325
# [37]	validation_0-rmse:2.38813	validation_1-rmse:2.03082
# [38]	validation_0-rmse:2.38318	validation_1-rmse:2.02111
# [39]	validation_0-rmse:2.37967	validation_1-rmse:2.01869
# [40]	validation_0-rmse:2.37739	validation_1-rmse:2.01434
# [41]	validation_0-rmse:2.37301	validation_1-rmse:2.00996
# [42]	validation_0-rmse:2.36874	validation_1-rmse:2.00718
# [43]	validation_0-rmse:2.36639	validation_1-rmse:2.00367
# [44]	validation_0-rmse:2.36269	validation_1-rmse:1.99844
# [45]	validation_0-rmse:2.35926	validation_1-rmse:1.99604
# [46]	validation_0-rmse:2.35684	validation_1-rmse:1.99289
# [47]	validation_0-rmse:2.35438	validation_1-rmse:1.99125
# [48]	validation_0-rmse:2.35176	validation_1-rmse:1.99116
# [49]	validation_0-rmse:2.35055	validation_1-rmse:1.99045
# [50]	validation_0-rmse:2.34844	validation_1-rmse:1.99016
# [51]	validation_0-rmse:2.34698	validation_1-rmse:1.99073
# [52]	validation_0-rmse:2.34707	validation_1-rmse:1.99009
# [53]	validation_0-rmse:2.34612	validation_1-rmse:1.9869
# [54]	validation_0-rmse:2.34424	validation_1-rmse:1.98502
# [55]	validation_0-rmse:2.34302	validation_1-rmse:1.98364
# [56]	validation_0-rmse:2.34089	validation_1-rmse:1.98338
# [57]	validation_0-rmse:2.33974	validation_1-rmse:1.98172
# [58]	validation_0-rmse:2.3392	validation_1-rmse:1.98081
# [59]	validation_0-rmse:2.33905	validation_1-rmse:1.98144
# [60]	validation_0-rmse:2.33777	validation_1-rmse:1.98204
# [61]	validation_0-rmse:2.33681	validation_1-rmse:1.98209
# [62]	validation_0-rmse:2.33631	validation_1-rmse:1.98158
# [63]	validation_0-rmse:2.33554	validation_1-rmse:1.98151
# [64]	validation_0-rmse:2.3341	validation_1-rmse:1.98084
# [65]	validation_0-rmse:2.33361	validation_1-rmse:1.98073
# [66]	validation_0-rmse:2.33298	validation_1-rmse:1.98067
# [67]	validation_0-rmse:2.33236	validation_1-rmse:1.98113
# [68]	validation_0-rmse:2.33035	validation_1-rmse:1.97954
# [69]	validation_0-rmse:2.33005	validation_1-rmse:1.97874
# [70]	validation_0-rmse:2.32952	validation_1-rmse:1.97929
# [71]	validation_0-rmse:2.32742	validation_1-rmse:1.97841
# [72]	validation_0-rmse:2.32467	validation_1-rmse:1.97878
# [73]	validation_0-rmse:2.32441	validation_1-rmse:1.97858
# [74]	validation_0-rmse:2.32207	validation_1-rmse:1.98172
# [75]	validation_0-rmse:2.3213	validation_1-rmse:1.98119
# [76]	validation_0-rmse:2.31997	validation_1-rmse:1.98122
# [77]	validation_0-rmse:2.31879	validation_1-rmse:1.98179
# [78]	validation_0-rmse:2.3173	validation_1-rmse:1.98122
# [79]	validation_0-rmse:2.31402	validation_1-rmse:1.97836
# [80]	validation_0-rmse:2.31344	validation_1-rmse:1.97854
# [81]	validation_0-rmse:2.31146	validation_1-rmse:1.97832
# [82]	validation_0-rmse:2.30913	validation_1-rmse:1.97958
# [83]	validation_0-rmse:2.30674	validation_1-rmse:1.97884
# [84]	validation_0-rmse:2.30645	validation_1-rmse:1.98133
# [85]	validation_0-rmse:2.3059	validation_1-rmse:1.98088
# [86]	validation_0-rmse:2.30406	validation_1-rmse:1.97955
# [87]	validation_0-rmse:2.30328	validation_1-rmse:1.98233
# [88]	validation_0-rmse:2.3027	validation_1-rmse:1.98113
# [89]	validation_0-rmse:2.30111	validation_1-rmse:1.97913
# [90]	validation_0-rmse:2.30059	validation_1-rmse:1.97879
# [91]	validation_0-rmse:2.2988	validation_1-rmse:1.97838
# [92]	validation_0-rmse:2.29717	validation_1-rmse:1.97813
# [93]	validation_0-rmse:2.29682	validation_1-rmse:1.97815
# [94]	validation_0-rmse:2.29647	validation_1-rmse:1.97807
# [95]	validation_0-rmse:2.29455	validation_1-rmse:1.97803
# [96]	validation_0-rmse:2.29356	validation_1-rmse:1.97863
# [97]	validation_0-rmse:2.29243	validation_1-rmse:1.97793
# [98]	validation_0-rmse:2.29143	validation_1-rmse:1.9776
# [99]	validation_0-rmse:2.29104	validation_1-rmse:1.97726
# [100]	validation_0-rmse:2.29022	validation_1-rmse:1.98122
# [101]	validation_0-rmse:2.28834	validation_1-rmse:1.98104
# [102]	validation_0-rmse:2.2868	validation_1-rmse:1.98083
# [103]	validation_0-rmse:2.28608	validation_1-rmse:1.98068
# [104]	validation_0-rmse:2.28471	validation_1-rmse:1.98082
# [105]	validation_0-rmse:2.28407	validation_1-rmse:1.98123
# [106]	validation_0-rmse:2.28354	validation_1-rmse:1.98239
# [107]	validation_0-rmse:2.28217	validation_1-rmse:1.98073
# [108]	validation_0-rmse:2.28145	validation_1-rmse:1.98028
# [109]	validation_0-rmse:2.2807	validation_1-rmse:1.98101
# [110]	validation_0-rmse:2.27961	validation_1-rmse:1.98123
# [111]	validation_0-rmse:2.27837	validation_1-rmse:1.9811
# [112]	validation_0-rmse:2.27779	validation_1-rmse:1.98134
# [113]	validation_0-rmse:2.27757	validation_1-rmse:1.98096
# [114]	validation_0-rmse:2.27645	validation_1-rmse:1.98127
# [115]	validation_0-rmse:2.27589	validation_1-rmse:1.98105
# [116]	validation_0-rmse:2.27486	validation_1-rmse:1.98087
# [117]	validation_0-rmse:2.2736	validation_1-rmse:1.98049
# [118]	validation_0-rmse:2.27339	validation_1-rmse:1.98038
# [119]	validation_0-rmse:2.27248	validation_1-rmse:1.98025
# Stopping. Best iteration:
# [99]	validation_0-rmse:2.29104	validation_1-rmse:1.97726
#
# [CV] END ....................max_depth=10, n_estimators=1200; total time=25.6min
# [18:18:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.31935	validation_1-rmse:5.40943
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.76053	validation_1-rmse:4.90505
# [2]	validation_0-rmse:6.26989	validation_1-rmse:4.50123
# [3]	validation_0-rmse:5.82531	validation_1-rmse:4.19954
# [4]	validation_0-rmse:5.43961	validation_1-rmse:3.87177
# [5]	validation_0-rmse:5.08638	validation_1-rmse:3.65085
# [6]	validation_0-rmse:4.77517	validation_1-rmse:3.43039
# [7]	validation_0-rmse:4.51069	validation_1-rmse:3.2333
# [8]	validation_0-rmse:4.28237	validation_1-rmse:3.07079
# [9]	validation_0-rmse:4.08188	validation_1-rmse:2.95399
# [10]	validation_0-rmse:3.89612	validation_1-rmse:2.80636
# [11]	validation_0-rmse:3.7397	validation_1-rmse:2.74282
# [12]	validation_0-rmse:3.60695	validation_1-rmse:2.7413
# [13]	validation_0-rmse:3.49043	validation_1-rmse:2.69663
# [14]	validation_0-rmse:3.39017	validation_1-rmse:2.69048
# [15]	validation_0-rmse:3.31064	validation_1-rmse:2.70797
# [16]	validation_0-rmse:3.24311	validation_1-rmse:2.73536
# [17]	validation_0-rmse:3.18959	validation_1-rmse:2.77071
# [18]	validation_0-rmse:3.14293	validation_1-rmse:2.80595
# [19]	validation_0-rmse:3.10155	validation_1-rmse:2.84787
# [20]	validation_0-rmse:3.06977	validation_1-rmse:2.89693
# [21]	validation_0-rmse:3.03813	validation_1-rmse:2.94677
# [22]	validation_0-rmse:3.01352	validation_1-rmse:2.99404
# [23]	validation_0-rmse:2.99518	validation_1-rmse:3.03812
# [24]	validation_0-rmse:2.97712	validation_1-rmse:3.08168
# [25]	validation_0-rmse:2.96383	validation_1-rmse:3.12328
# [26]	validation_0-rmse:2.94959	validation_1-rmse:3.13122
# [27]	validation_0-rmse:2.93782	validation_1-rmse:3.17919
# [28]	validation_0-rmse:2.93155	validation_1-rmse:3.21851
# [29]	validation_0-rmse:2.92191	validation_1-rmse:3.21934
# [30]	validation_0-rmse:2.91781	validation_1-rmse:3.25805
# [31]	validation_0-rmse:2.91206	validation_1-rmse:3.28982
# [32]	validation_0-rmse:2.90649	validation_1-rmse:3.32079
# [33]	validation_0-rmse:2.90396	validation_1-rmse:3.35089
# [34]	validation_0-rmse:2.89857	validation_1-rmse:3.35306
# Stopping. Best iteration:
# [14]	validation_0-rmse:3.39017	validation_1-rmse:2.69048
#
# [CV] END ....................max_depth=10, n_estimators=1200; total time= 8.1min
# [18:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.32574	validation_1-rmse:5.44952
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.76689	validation_1-rmse:4.9799
# [2]	validation_0-rmse:6.25772	validation_1-rmse:4.5559
# [3]	validation_0-rmse:5.79011	validation_1-rmse:4.2173
# [4]	validation_0-rmse:5.37759	validation_1-rmse:3.87966
# [5]	validation_0-rmse:5.00799	validation_1-rmse:3.61938
# [6]	validation_0-rmse:4.67282	validation_1-rmse:3.4079
# [7]	validation_0-rmse:4.37348	validation_1-rmse:3.196
# [8]	validation_0-rmse:4.11589	validation_1-rmse:3.03903
# [9]	validation_0-rmse:3.87651	validation_1-rmse:2.87466
# [10]	validation_0-rmse:3.66196	validation_1-rmse:2.75892
# [11]	validation_0-rmse:3.46785	validation_1-rmse:2.67484
# [12]	validation_0-rmse:3.29665	validation_1-rmse:2.58118
# [13]	validation_0-rmse:3.14746	validation_1-rmse:2.51473
# [14]	validation_0-rmse:3.01486	validation_1-rmse:2.44764
# [15]	validation_0-rmse:2.89469	validation_1-rmse:2.40679
# [16]	validation_0-rmse:2.78891	validation_1-rmse:2.3603
# [17]	validation_0-rmse:2.69602	validation_1-rmse:2.31093
# [18]	validation_0-rmse:2.61083	validation_1-rmse:2.27247
# [19]	validation_0-rmse:2.54196	validation_1-rmse:2.23558
# [20]	validation_0-rmse:2.47325	validation_1-rmse:2.21162
# [21]	validation_0-rmse:2.4175	validation_1-rmse:2.1758
# [22]	validation_0-rmse:2.36781	validation_1-rmse:2.16424
# [23]	validation_0-rmse:2.32237	validation_1-rmse:2.16371
# [24]	validation_0-rmse:2.28142	validation_1-rmse:2.15694
# [25]	validation_0-rmse:2.24496	validation_1-rmse:2.14955
# [26]	validation_0-rmse:2.21312	validation_1-rmse:2.14404
# [27]	validation_0-rmse:2.18458	validation_1-rmse:2.14049
# [28]	validation_0-rmse:2.15624	validation_1-rmse:2.1311
# [29]	validation_0-rmse:2.13316	validation_1-rmse:2.12578
# [30]	validation_0-rmse:2.11253	validation_1-rmse:2.12848
# [31]	validation_0-rmse:2.09573	validation_1-rmse:2.13283
# [32]	validation_0-rmse:2.07935	validation_1-rmse:2.13772
# [33]	validation_0-rmse:2.06549	validation_1-rmse:2.14008
# [34]	validation_0-rmse:2.05331	validation_1-rmse:2.14451
# [35]	validation_0-rmse:2.04269	validation_1-rmse:2.14025
# [36]	validation_0-rmse:2.03325	validation_1-rmse:2.13758
# [37]	validation_0-rmse:2.02331	validation_1-rmse:2.13158
# [38]	validation_0-rmse:2.01626	validation_1-rmse:2.12682
# [39]	validation_0-rmse:2.00874	validation_1-rmse:2.1266
# [40]	validation_0-rmse:2.00234	validation_1-rmse:2.12868
# [41]	validation_0-rmse:1.99638	validation_1-rmse:2.1271
# [42]	validation_0-rmse:1.99202	validation_1-rmse:2.12212
# [43]	validation_0-rmse:1.98628	validation_1-rmse:2.1205
# [44]	validation_0-rmse:1.98147	validation_1-rmse:2.12392
# [45]	validation_0-rmse:1.97817	validation_1-rmse:2.12708
# [46]	validation_0-rmse:1.97523	validation_1-rmse:2.13183
# [47]	validation_0-rmse:1.97161	validation_1-rmse:2.13579
# [48]	validation_0-rmse:1.96917	validation_1-rmse:2.13514
# [49]	validation_0-rmse:1.96698	validation_1-rmse:2.13421
# [50]	validation_0-rmse:1.96417	validation_1-rmse:2.13486
# [51]	validation_0-rmse:1.96182	validation_1-rmse:2.13529
# [52]	validation_0-rmse:1.95915	validation_1-rmse:2.13898
# [53]	validation_0-rmse:1.9576	validation_1-rmse:2.14251
# [54]	validation_0-rmse:1.95595	validation_1-rmse:2.14184
# [55]	validation_0-rmse:1.95389	validation_1-rmse:2.14147
# [56]	validation_0-rmse:1.95233	validation_1-rmse:2.14499
# [57]	validation_0-rmse:1.95126	validation_1-rmse:2.14478
# [58]	validation_0-rmse:1.95027	validation_1-rmse:2.14583
# [59]	validation_0-rmse:1.9479	validation_1-rmse:2.14584
# [60]	validation_0-rmse:1.94655	validation_1-rmse:2.14543
# [61]	validation_0-rmse:1.94567	validation_1-rmse:2.14524
# [62]	validation_0-rmse:1.9445	validation_1-rmse:2.14492
# [63]	validation_0-rmse:1.94325	validation_1-rmse:2.14557
# Stopping. Best iteration:
# [43]	validation_0-rmse:1.98628	validation_1-rmse:2.1205
#
# [CV] END ....................max_depth=15, n_estimators=1000; total time=24.2min
# [18:50:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.32737	validation_1-rmse:5.49108
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.76468	validation_1-rmse:4.9751
# [2]	validation_0-rmse:6.26117	validation_1-rmse:4.64249
# [3]	validation_0-rmse:5.8103	validation_1-rmse:4.34432
# [4]	validation_0-rmse:5.41183	validation_1-rmse:4.08215
# [5]	validation_0-rmse:5.04419	validation_1-rmse:3.81287
# [6]	validation_0-rmse:4.71829	validation_1-rmse:3.58468
# [7]	validation_0-rmse:4.4353	validation_1-rmse:3.37488
# [8]	validation_0-rmse:4.18683	validation_1-rmse:3.18047
# [9]	validation_0-rmse:3.96075	validation_1-rmse:3.1327
# [10]	validation_0-rmse:3.75866	validation_1-rmse:3.00329
# [11]	validation_0-rmse:3.58116	validation_1-rmse:2.88032
# [12]	validation_0-rmse:3.43316	validation_1-rmse:2.84039
# [13]	validation_0-rmse:3.29956	validation_1-rmse:2.76794
# [14]	validation_0-rmse:3.17999	validation_1-rmse:2.68842
# [15]	validation_0-rmse:3.07912	validation_1-rmse:2.63596
# [16]	validation_0-rmse:2.98359	validation_1-rmse:2.57973
# [17]	validation_0-rmse:2.90546	validation_1-rmse:2.53304
# [18]	validation_0-rmse:2.83499	validation_1-rmse:2.49336
# [19]	validation_0-rmse:2.77379	validation_1-rmse:2.4627
# [20]	validation_0-rmse:2.71929	validation_1-rmse:2.46068
# [21]	validation_0-rmse:2.67089	validation_1-rmse:2.43958
# [22]	validation_0-rmse:2.62905	validation_1-rmse:2.45527
# [23]	validation_0-rmse:2.59061	validation_1-rmse:2.44779
# [24]	validation_0-rmse:2.55643	validation_1-rmse:2.44083
# [25]	validation_0-rmse:2.52635	validation_1-rmse:2.43091
# [26]	validation_0-rmse:2.50104	validation_1-rmse:2.41779
# [27]	validation_0-rmse:2.48025	validation_1-rmse:2.40693
# [28]	validation_0-rmse:2.46238	validation_1-rmse:2.39676
# [29]	validation_0-rmse:2.43742	validation_1-rmse:2.39547
# [30]	validation_0-rmse:2.42402	validation_1-rmse:2.39371
# [31]	validation_0-rmse:2.40458	validation_1-rmse:2.38955
# [32]	validation_0-rmse:2.38746	validation_1-rmse:2.38807
# [33]	validation_0-rmse:2.37144	validation_1-rmse:2.38898
# [34]	validation_0-rmse:2.35807	validation_1-rmse:2.3885
# [35]	validation_0-rmse:2.35076	validation_1-rmse:2.38897
# [36]	validation_0-rmse:2.34306	validation_1-rmse:2.38774
# [37]	validation_0-rmse:2.33562	validation_1-rmse:2.38365
# [38]	validation_0-rmse:2.32584	validation_1-rmse:2.38311
# [39]	validation_0-rmse:2.31685	validation_1-rmse:2.38347
# [40]	validation_0-rmse:2.30967	validation_1-rmse:2.38443
# [41]	validation_0-rmse:2.30517	validation_1-rmse:2.38476
# [42]	validation_0-rmse:2.30026	validation_1-rmse:2.3846
# [43]	validation_0-rmse:2.29592	validation_1-rmse:2.38477
# [44]	validation_0-rmse:2.29264	validation_1-rmse:2.38474
# [45]	validation_0-rmse:2.28866	validation_1-rmse:2.38361
# [46]	validation_0-rmse:2.28569	validation_1-rmse:2.38415
# [47]	validation_0-rmse:2.28198	validation_1-rmse:2.38563
# [48]	validation_0-rmse:2.27974	validation_1-rmse:2.38466
# [49]	validation_0-rmse:2.27754	validation_1-rmse:2.38524
# [50]	validation_0-rmse:2.27608	validation_1-rmse:2.38483
# [51]	validation_0-rmse:2.27359	validation_1-rmse:2.38433
# [52]	validation_0-rmse:2.27202	validation_1-rmse:2.38405
# [53]	validation_0-rmse:2.27002	validation_1-rmse:2.38364
# [54]	validation_0-rmse:2.26842	validation_1-rmse:2.38406
# [55]	validation_0-rmse:2.26742	validation_1-rmse:2.38469
# [56]	validation_0-rmse:2.26611	validation_1-rmse:2.38492
# [57]	validation_0-rmse:2.26446	validation_1-rmse:2.38499
# [58]	validation_0-rmse:2.26305	validation_1-rmse:2.38616
# Stopping. Best iteration:
# [38]	validation_0-rmse:2.32584	validation_1-rmse:2.38311
#
# [CV] END ....................max_depth=15, n_estimators=1000; total time=22.2min
# [19:13:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.3367	validation_1-rmse:5.48442
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.77039	validation_1-rmse:5.05136
# [2]	validation_0-rmse:6.25365	validation_1-rmse:4.68831
# [3]	validation_0-rmse:5.79092	validation_1-rmse:4.35169
# [4]	validation_0-rmse:5.39155	validation_1-rmse:4.05621
# [5]	validation_0-rmse:5.01578	validation_1-rmse:3.80212
# [6]	validation_0-rmse:4.68002	validation_1-rmse:3.5555
# [7]	validation_0-rmse:4.39966	validation_1-rmse:3.34524
# [8]	validation_0-rmse:4.12595	validation_1-rmse:3.16472
# [9]	validation_0-rmse:3.89581	validation_1-rmse:2.9869
# [10]	validation_0-rmse:3.68679	validation_1-rmse:2.83716
# [11]	validation_0-rmse:3.50295	validation_1-rmse:2.70616
# [13]	validation_0-rmse:3.19519	validation_1-rmse:2.53387
# [14]	validation_0-rmse:3.07037	validation_1-rmse:2.46545
# [15]	validation_0-rmse:2.95808	validation_1-rmse:2.40666
# [16]	validation_0-rmse:2.85965	validation_1-rmse:2.3589
# [17]	validation_0-rmse:2.77164	validation_1-rmse:2.31598
# [18]	validation_0-rmse:2.69348	validation_1-rmse:2.28054
# [19]	validation_0-rmse:2.62505	validation_1-rmse:2.2518
# [20]	validation_0-rmse:2.56398	validation_1-rmse:2.22125
# [21]	validation_0-rmse:2.51082	validation_1-rmse:2.19298
# [22]	validation_0-rmse:2.46083	validation_1-rmse:2.16912
# [23]	validation_0-rmse:2.41915	validation_1-rmse:2.15049
# [24]	validation_0-rmse:2.38348	validation_1-rmse:2.13477
# [25]	validation_0-rmse:2.35113	validation_1-rmse:2.11363
# [26]	validation_0-rmse:2.32038	validation_1-rmse:2.10124
# [27]	validation_0-rmse:2.29475	validation_1-rmse:2.08517
# [28]	validation_0-rmse:2.27315	validation_1-rmse:2.07784
# [29]	validation_0-rmse:2.25354	validation_1-rmse:2.06981
# [30]	validation_0-rmse:2.23566	validation_1-rmse:2.06248
# [31]	validation_0-rmse:2.22166	validation_1-rmse:2.05712
# [32]	validation_0-rmse:2.20821	validation_1-rmse:2.05262
# [33]	validation_0-rmse:2.19658	validation_1-rmse:2.04871
# [34]	validation_0-rmse:2.18466	validation_1-rmse:2.04424
# [35]	validation_0-rmse:2.17548	validation_1-rmse:2.04385
# [36]	validation_0-rmse:2.16723	validation_1-rmse:2.04139
# [37]	validation_0-rmse:2.16087	validation_1-rmse:2.03809
# [38]	validation_0-rmse:2.15552	validation_1-rmse:2.03397
# [39]	validation_0-rmse:2.14943	validation_1-rmse:2.0311
# [40]	validation_0-rmse:2.14435	validation_1-rmse:2.02913
# [41]	validation_0-rmse:2.14032	validation_1-rmse:2.02849
# [42]	validation_0-rmse:2.1373	validation_1-rmse:2.02603
# [43]	validation_0-rmse:2.13475	validation_1-rmse:2.02322
# [44]	validation_0-rmse:2.13255	validation_1-rmse:2.02233
# [45]	validation_0-rmse:2.13049	validation_1-rmse:2.02032
# [46]	validation_0-rmse:2.12876	validation_1-rmse:2.01988
# [47]	validation_0-rmse:2.12629	validation_1-rmse:2.01926
# [48]	validation_0-rmse:2.12452	validation_1-rmse:2.01769
# [49]	validation_0-rmse:2.12257	validation_1-rmse:2.01602
# [50]	validation_0-rmse:2.12109	validation_1-rmse:2.0151
# [51]	validation_0-rmse:2.11895	validation_1-rmse:2.01488
# [52]	validation_0-rmse:2.1174	validation_1-rmse:2.01432
# [53]	validation_0-rmse:2.1162	validation_1-rmse:2.01334
# [54]	validation_0-rmse:2.11441	validation_1-rmse:2.01336
# [55]	validation_0-rmse:2.11393	validation_1-rmse:2.01217
# [56]	validation_0-rmse:2.11325	validation_1-rmse:2.01182
# [57]	validation_0-rmse:2.11237	validation_1-rmse:2.01161
# [58]	validation_0-rmse:2.11191	validation_1-rmse:2.01209
# [59]	validation_0-rmse:2.11088	validation_1-rmse:2.01207
# [60]	validation_0-rmse:2.11027	validation_1-rmse:2.01222
# [61]	validation_0-rmse:2.1094	validation_1-rmse:2.01156
# [62]	validation_0-rmse:2.10886	validation_1-rmse:2.01141
# [63]	validation_0-rmse:2.10799	validation_1-rmse:2.01465
# [64]	validation_0-rmse:2.10811	validation_1-rmse:2.01472
# [65]	validation_0-rmse:2.10795	validation_1-rmse:2.01361
# [66]	validation_0-rmse:2.10759	validation_1-rmse:2.01303
# [67]	validation_0-rmse:2.10774	validation_1-rmse:2.01302
# [68]	validation_0-rmse:2.10783	validation_1-rmse:2.01272
# [69]	validation_0-rmse:2.10792	validation_1-rmse:2.01248
# [70]	validation_0-rmse:2.10804	validation_1-rmse:2.01246
# [71]	validation_0-rmse:2.1078	validation_1-rmse:2.01199
# [72]	validation_0-rmse:2.10781	validation_1-rmse:2.01233
# [73]	validation_0-rmse:2.1074	validation_1-rmse:2.01178
# [74]	validation_0-rmse:2.10755	validation_1-rmse:2.01174
# [75]	validation_0-rmse:2.10775	validation_1-rmse:2.01171
# [76]	validation_0-rmse:2.10791	validation_1-rmse:2.01456
# [77]	validation_0-rmse:2.10796	validation_1-rmse:2.01406
# [78]	validation_0-rmse:2.10728	validation_1-rmse:2.01429
# [79]	validation_0-rmse:2.10646	validation_1-rmse:2.01396
# [80]	validation_0-rmse:2.10627	validation_1-rmse:2.01423
# [81]	validation_0-rmse:2.10582	validation_1-rmse:2.01382
# [82]	validation_0-rmse:2.10556	validation_1-rmse:2.01367
# Stopping. Best iteration:
# [62]	validation_0-rmse:2.10886	validation_1-rmse:2.01141
#
# [CV] END ....................max_depth=15, n_estimators=1000; total time=29.0min
# [19:42:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.31869	validation_1-rmse:5.40188
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.75233	validation_1-rmse:4.89136
# [2]	validation_0-rmse:6.25715	validation_1-rmse:4.48352
# [3]	validation_0-rmse:5.80675	validation_1-rmse:4.17559
# [4]	validation_0-rmse:5.41522	validation_1-rmse:3.85936
# [5]	validation_0-rmse:5.0568	validation_1-rmse:3.65033
# [6]	validation_0-rmse:4.74866	validation_1-rmse:3.47135
# [7]	validation_0-rmse:4.47946	validation_1-rmse:3.29009
# [8]	validation_0-rmse:4.24575	validation_1-rmse:3.13711
# [9]	validation_0-rmse:4.03996	validation_1-rmse:3.02578
# [10]	validation_0-rmse:3.85155	validation_1-rmse:2.94706
# [11]	validation_0-rmse:3.70049	validation_1-rmse:2.89876
# [12]	validation_0-rmse:3.55637	validation_1-rmse:2.81883
# [13]	validation_0-rmse:3.43713	validation_1-rmse:2.78335
# [14]	validation_0-rmse:3.33804	validation_1-rmse:2.78989
# [15]	validation_0-rmse:3.25588	validation_1-rmse:2.81123
# [16]	validation_0-rmse:3.1858	validation_1-rmse:2.84124
# [17]	validation_0-rmse:3.12781	validation_1-rmse:2.87919
# [18]	validation_0-rmse:3.07923	validation_1-rmse:2.9305
# [19]	validation_0-rmse:3.03915	validation_1-rmse:2.9852
# [20]	validation_0-rmse:3.00685	validation_1-rmse:3.03972
# [21]	validation_0-rmse:2.9794	validation_1-rmse:3.09058
# [22]	validation_0-rmse:2.9585	validation_1-rmse:3.1437
# [23]	validation_0-rmse:2.94141	validation_1-rmse:3.19153
# [24]	validation_0-rmse:2.92248	validation_1-rmse:3.23693
# [25]	validation_0-rmse:2.90766	validation_1-rmse:3.28173
# [26]	validation_0-rmse:2.89489	validation_1-rmse:3.32656
# [27]	validation_0-rmse:2.88377	validation_1-rmse:3.37004
# [28]	validation_0-rmse:2.87364	validation_1-rmse:3.41169
# [29]	validation_0-rmse:2.86589	validation_1-rmse:3.45181
# [30]	validation_0-rmse:2.85893	validation_1-rmse:3.49221
# [31]	validation_0-rmse:2.85258	validation_1-rmse:3.52928
# [32]	validation_0-rmse:2.84832	validation_1-rmse:3.56367
# [33]	validation_0-rmse:2.84519	validation_1-rmse:3.59714
# Stopping. Best iteration:
# [13]	validation_0-rmse:3.43713	validation_1-rmse:2.78335
#
# ...
# [58]	validation_0-rmse:1.95027	validation_1-rmse:2.14583
# [59]	validation_0-rmse:1.9479	validation_1-rmse:2.14584
# [60]	validation_0-rmse:1.94655	validation_1-rmse:2.14543
# [61]	validation_0-rmse:1.94567	validation_1-rmse:2.14524
# [62]	validation_0-rmse:1.9445	validation_1-rmse:2.14492
# [63]	validation_0-rmse:1.94325	validation_1-rmse:2.14557
# Stopping. Best iteration:
# [43]	validation_0-rmse:1.98628	validation_1-rmse:2.1205
#
# [CV] END ....................max_depth=15, n_estimators=1200; total time=23.4min
# [20:18:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.32737	validation_1-rmse:5.49108
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.76468	validation_1-rmse:4.9751
# [2]	validation_0-rmse:6.26117	validation_1-rmse:4.64249
# [3]	validation_0-rmse:5.8103	validation_1-rmse:4.34432
# [4]	validation_0-rmse:5.41183	validation_1-rmse:4.08215
# [5]	validation_0-rmse:5.04419	validation_1-rmse:3.81287
# [6]	validation_0-rmse:4.71829	validation_1-rmse:3.58468
# [7]	validation_0-rmse:4.4353	validation_1-rmse:3.37488
# [8]	validation_0-rmse:4.18683	validation_1-rmse:3.18047
# [9]	validation_0-rmse:3.96075	validation_1-rmse:3.1327
# [10]	validation_0-rmse:3.75866	validation_1-rmse:3.00329
# [11]	validation_0-rmse:3.58116	validation_1-rmse:2.88032
# [12]	validation_0-rmse:3.43316	validation_1-rmse:2.84039
# [13]	validation_0-rmse:3.29956	validation_1-rmse:2.76794
# [14]	validation_0-rmse:3.17999	validation_1-rmse:2.68842
# [15]	validation_0-rmse:3.07912	validation_1-rmse:2.63596
# [16]	validation_0-rmse:2.98359	validation_1-rmse:2.57973
# [17]	validation_0-rmse:2.90546	validation_1-rmse:2.53304
# [18]	validation_0-rmse:2.83499	validation_1-rmse:2.49336
# [19]	validation_0-rmse:2.77379	validation_1-rmse:2.4627
# [20]	validation_0-rmse:2.71929	validation_1-rmse:2.46068
# [21]	validation_0-rmse:2.67089	validation_1-rmse:2.43958
# [22]	validation_0-rmse:2.62905	validation_1-rmse:2.45527
# [23]	validation_0-rmse:2.59061	validation_1-rmse:2.44779
# [24]	validation_0-rmse:2.55643	validation_1-rmse:2.44083
# [25]	validation_0-rmse:2.52635	validation_1-rmse:2.43091
# [26]	validation_0-rmse:2.50104	validation_1-rmse:2.41779
# [27]	validation_0-rmse:2.48025	validation_1-rmse:2.40693
# [28]	validation_0-rmse:2.46238	validation_1-rmse:2.39676
# [29]	validation_0-rmse:2.43742	validation_1-rmse:2.39547
# [30]	validation_0-rmse:2.42402	validation_1-rmse:2.39371
# [31]	validation_0-rmse:2.40458	validation_1-rmse:2.38955
# [32]	validation_0-rmse:2.38746	validation_1-rmse:2.38807
# [33]	validation_0-rmse:2.37144	validation_1-rmse:2.38898
# [34]	validation_0-rmse:2.35807	validation_1-rmse:2.3885
# [35]	validation_0-rmse:2.35076	validation_1-rmse:2.38897
# [36]	validation_0-rmse:2.34306	validation_1-rmse:2.38774
# [37]	validation_0-rmse:2.33562	validation_1-rmse:2.38365
# [38]	validation_0-rmse:2.32584	validation_1-rmse:2.38311
# [39]	validation_0-rmse:2.31685	validation_1-rmse:2.38347
# [40]	validation_0-rmse:2.30967	validation_1-rmse:2.38443
# [41]	validation_0-rmse:2.30517	validation_1-rmse:2.38476
# [42]	validation_0-rmse:2.30026	validation_1-rmse:2.3846
# [43]	validation_0-rmse:2.29592	validation_1-rmse:2.38477
# [44]	validation_0-rmse:2.29264	validation_1-rmse:2.38474
# [45]	validation_0-rmse:2.28866	validation_1-rmse:2.38361
# [46]	validation_0-rmse:2.28569	validation_1-rmse:2.38415
# [47]	validation_0-rmse:2.28198	validation_1-rmse:2.38563
# [48]	validation_0-rmse:2.27974	validation_1-rmse:2.38466
# [49]	validation_0-rmse:2.27754	validation_1-rmse:2.38524
# [50]	validation_0-rmse:2.27608	validation_1-rmse:2.38483
# [51]	validation_0-rmse:2.27359	validation_1-rmse:2.38433
# [52]	validation_0-rmse:2.27202	validation_1-rmse:2.38405
# [53]	validation_0-rmse:2.27002	validation_1-rmse:2.38364
# [54]	validation_0-rmse:2.26842	validation_1-rmse:2.38406
# [55]	validation_0-rmse:2.26742	validation_1-rmse:2.38469
# [56]	validation_0-rmse:2.26611	validation_1-rmse:2.38492
# [57]	validation_0-rmse:2.26446	validation_1-rmse:2.38499
# [58]	validation_0-rmse:2.26305	validation_1-rmse:2.38616
# Stopping. Best iteration:
# [38]	validation_0-rmse:2.32584	validation_1-rmse:2.38311
#
# [CV] END ....................max_depth=15, n_estimators=1200; total time=22.6min
# [20:41:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.3367	validation_1-rmse:5.48442
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.77039	validation_1-rmse:5.05136
# [2]	validation_0-rmse:6.25365	validation_1-rmse:4.68831
# [3]	validation_0-rmse:5.79092	validation_1-rmse:4.35169
# [4]	validation_0-rmse:5.39155	validation_1-rmse:4.05621
# [5]	validation_0-rmse:5.01578	validation_1-rmse:3.80212
# [6]	validation_0-rmse:4.68002	validation_1-rmse:3.5555
# [7]	validation_0-rmse:4.39966	validation_1-rmse:3.34524
# [8]	validation_0-rmse:4.12595	validation_1-rmse:3.16472
# [9]	validation_0-rmse:3.89581	validation_1-rmse:2.9869
# [10]	validation_0-rmse:3.68679	validation_1-rmse:2.83716
# [11]	validation_0-rmse:3.50295	validation_1-rmse:2.70616
# [12]	validation_0-rmse:3.34172	validation_1-rmse:2.6243
# [13]	validation_0-rmse:3.19519	validation_1-rmse:2.53387
# [14]	validation_0-rmse:3.07037	validation_1-rmse:2.46545
# [15]	validation_0-rmse:2.95808	validation_1-rmse:2.40666
# [16]	validation_0-rmse:2.85965	validation_1-rmse:2.3589
# [17]	validation_0-rmse:2.77164	validation_1-rmse:2.31598
# [18]	validation_0-rmse:2.69348	validation_1-rmse:2.28054
# [19]	validation_0-rmse:2.62505	validation_1-rmse:2.2518
# [20]	validation_0-rmse:2.56398	validation_1-rmse:2.22125
# [21]	validation_0-rmse:2.51082	validation_1-rmse:2.19298
# [22]	validation_0-rmse:2.46083	validation_1-rmse:2.16912
# [23]	validation_0-rmse:2.41915	validation_1-rmse:2.15049
# [24]	validation_0-rmse:2.38348	validation_1-rmse:2.13477
# [25]	validation_0-rmse:2.35113	validation_1-rmse:2.11363
# [26]	validation_0-rmse:2.32038	validation_1-rmse:2.10124
# [27]	validation_0-rmse:2.29475	validation_1-rmse:2.08517
# [28]	validation_0-rmse:2.27315	validation_1-rmse:2.07784
# [29]	validation_0-rmse:2.25354	validation_1-rmse:2.06981
# [30]	validation_0-rmse:2.23566	validation_1-rmse:2.06248
# [31]	validation_0-rmse:2.22166	validation_1-rmse:2.05712
# [32]	validation_0-rmse:2.20821	validation_1-rmse:2.05262
# [33]	validation_0-rmse:2.19658	validation_1-rmse:2.04871
# [34]	validation_0-rmse:2.18466	validation_1-rmse:2.04424
# [35]	validation_0-rmse:2.17548	validation_1-rmse:2.04385
# [36]	validation_0-rmse:2.16723	validation_1-rmse:2.04139
# [37]	validation_0-rmse:2.16087	validation_1-rmse:2.03809
# [38]	validation_0-rmse:2.15552	validation_1-rmse:2.03397
# [39]	validation_0-rmse:2.14943	validation_1-rmse:2.0311
# [40]	validation_0-rmse:2.14435	validation_1-rmse:2.02913
# [41]	validation_0-rmse:2.14032	validation_1-rmse:2.02849
# [42]	validation_0-rmse:2.1373	validation_1-rmse:2.02603
# [43]	validation_0-rmse:2.13475	validation_1-rmse:2.02322
# [44]	validation_0-rmse:2.13255	validation_1-rmse:2.02233
# [45]	validation_0-rmse:2.13049	validation_1-rmse:2.02032
# [46]	validation_0-rmse:2.12876	validation_1-rmse:2.01988
# [47]	validation_0-rmse:2.12629	validation_1-rmse:2.01926
# [48]	validation_0-rmse:2.12452	validation_1-rmse:2.01769
# [49]	validation_0-rmse:2.12257	validation_1-rmse:2.01602
# [50]	validation_0-rmse:2.12109	validation_1-rmse:2.0151
# [51]	validation_0-rmse:2.11895	validation_1-rmse:2.01488
# [52]	validation_0-rmse:2.1174	validation_1-rmse:2.01432
# [53]	validation_0-rmse:2.1162	validation_1-rmse:2.01334
# [54]	validation_0-rmse:2.11441	validation_1-rmse:2.01336
# [55]	validation_0-rmse:2.11393	validation_1-rmse:2.01217
# [56]	validation_0-rmse:2.11325	validation_1-rmse:2.01182
# [57]	validation_0-rmse:2.11237	validation_1-rmse:2.01161
# [58]	validation_0-rmse:2.11191	validation_1-rmse:2.01209
# [59]	validation_0-rmse:2.11088	validation_1-rmse:2.01207
# [60]	validation_0-rmse:2.11027	validation_1-rmse:2.01222
# [61]	validation_0-rmse:2.1094	validation_1-rmse:2.01156
# [62]	validation_0-rmse:2.10886	validation_1-rmse:2.01141
# [63]	validation_0-rmse:2.10799	validation_1-rmse:2.01465
# [64]	validation_0-rmse:2.10811	validation_1-rmse:2.01472
# [65]	validation_0-rmse:2.10795	validation_1-rmse:2.01361
# [66]	validation_0-rmse:2.10759	validation_1-rmse:2.01303
# [67]	validation_0-rmse:2.10774	validation_1-rmse:2.01302
# [68]	validation_0-rmse:2.10783	validation_1-rmse:2.01272
# [69]	validation_0-rmse:2.10792	validation_1-rmse:2.01248
# [70]	validation_0-rmse:2.10804	validation_1-rmse:2.01246
# [71]	validation_0-rmse:2.1078	validation_1-rmse:2.01199
# [72]	validation_0-rmse:2.10781	validation_1-rmse:2.01233
# [73]	validation_0-rmse:2.1074	validation_1-rmse:2.01178
# [74]	validation_0-rmse:2.10755	validation_1-rmse:2.01174
# [75]	validation_0-rmse:2.10775	validation_1-rmse:2.01171
# [76]	validation_0-rmse:2.10791	validation_1-rmse:2.01456
# [77]	validation_0-rmse:2.10796	validation_1-rmse:2.01406
# [78]	validation_0-rmse:2.10728	validation_1-rmse:2.01429
# [79]	validation_0-rmse:2.10646	validation_1-rmse:2.01396
# [80]	validation_0-rmse:2.10627	validation_1-rmse:2.01423
# [81]	validation_0-rmse:2.10582	validation_1-rmse:2.01382
# [82]	validation_0-rmse:2.10556	validation_1-rmse:2.01367
# Stopping. Best iteration:
# [62]	validation_0-rmse:2.10886	validation_1-rmse:2.01141
#
# [CV] END ....................max_depth=15, n_estimators=1200; total time=28.8min
# [21:10:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.31869	validation_1-rmse:5.40188
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.75233	validation_1-rmse:4.89136
# [2]	validation_0-rmse:6.25715	validation_1-rmse:4.48352
# [3]	validation_0-rmse:5.80675	validation_1-rmse:4.17559
# [4]	validation_0-rmse:5.41522	validation_1-rmse:3.85936
# [5]	validation_0-rmse:5.0568	validation_1-rmse:3.65033
# [6]	validation_0-rmse:4.74866	validation_1-rmse:3.47135
# [7]	validation_0-rmse:4.47946	validation_1-rmse:3.29009
# [8]	validation_0-rmse:4.24575	validation_1-rmse:3.13711
# [9]	validation_0-rmse:4.03996	validation_1-rmse:3.02578
# [10]	validation_0-rmse:3.85155	validation_1-rmse:2.94706
# [11]	validation_0-rmse:3.70049	validation_1-rmse:2.89876
# [12]	validation_0-rmse:3.55637	validation_1-rmse:2.81883
# [13]	validation_0-rmse:3.43713	validation_1-rmse:2.78335
# [14]	validation_0-rmse:3.33804	validation_1-rmse:2.78989
# [15]	validation_0-rmse:3.25588	validation_1-rmse:2.81123
# [16]	validation_0-rmse:3.1858	validation_1-rmse:2.84124
# [17]	validation_0-rmse:3.12781	validation_1-rmse:2.87919
# [18]	validation_0-rmse:3.07923	validation_1-rmse:2.9305
# [19]	validation_0-rmse:3.03915	validation_1-rmse:2.9852
# [20]	validation_0-rmse:3.00685	validation_1-rmse:3.03972
# [21]	validation_0-rmse:2.9794	validation_1-rmse:3.09058
# [22]	validation_0-rmse:2.9585	validation_1-rmse:3.1437
# [23]	validation_0-rmse:2.94141	validation_1-rmse:3.19153
# [24]	validation_0-rmse:2.92248	validation_1-rmse:3.23693
# [25]	validation_0-rmse:2.90766	validation_1-rmse:3.28173
# [26]	validation_0-rmse:2.89489	validation_1-rmse:3.32656
# [27]	validation_0-rmse:2.88377	validation_1-rmse:3.37004
# [28]	validation_0-rmse:2.87364	validation_1-rmse:3.41169
# [29]	validation_0-rmse:2.86589	validation_1-rmse:3.45181
# [30]	validation_0-rmse:2.85893	validation_1-rmse:3.49221
# [31]	validation_0-rmse:2.85258	validation_1-rmse:3.52928
# [32]	validation_0-rmse:2.84832	validation_1-rmse:3.56367
# [33]	validation_0-rmse:2.84519	validation_1-rmse:3.59714
# Stopping. Best iteration:
# [13]	validation_0-rmse:3.43713	validation_1-rmse:2.78335
#
# [CV] END ....................max_depth=15, n_estimators=1200; total time=12.1min
# [21:22:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.30797	validation_1-rmse:5.42863
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:6.71925	validation_1-rmse:4.98274
# [2]	validation_0-rmse:6.19095	validation_1-rmse:4.61664
# [3]	validation_0-rmse:5.71031	validation_1-rmse:4.2992
# [4]	validation_0-rmse:5.28337	validation_1-rmse:4.17877
# [5]	validation_0-rmse:4.89129	validation_1-rmse:3.88011
# [6]	validation_0-rmse:4.53479	validation_1-rmse:3.62962
# [7]	validation_0-rmse:4.21547	validation_1-rmse:3.44009
# [8]	validation_0-rmse:3.93312	validation_1-rmse:3.25656
# [9]	validation_0-rmse:3.67744	validation_1-rmse:3.07905
# [10]	validation_0-rmse:3.44639	validation_1-rmse:2.94991
# [11]	validation_0-rmse:3.24005	validation_1-rmse:2.84865
# [12]	validation_0-rmse:3.05209	validation_1-rmse:2.74793
# [13]	validation_0-rmse:2.88227	validation_1-rmse:2.64632
# [14]	validation_0-rmse:2.73077	validation_1-rmse:2.57203
# [15]	validation_0-rmse:2.59351	validation_1-rmse:2.48019
# [16]	validation_0-rmse:2.47286	validation_1-rmse:2.41437
# [17]	validation_0-rmse:2.36186	validation_1-rmse:2.35786
# [18]	validation_0-rmse:2.26375	validation_1-rmse:2.30895
# [19]	validation_0-rmse:2.17588	validation_1-rmse:2.2673
# [20]	validation_0-rmse:2.09701	validation_1-rmse:2.24191
# [21]	validation_0-rmse:2.02684	validation_1-rmse:2.21468
# [22]	validation_0-rmse:1.96541	validation_1-rmse:2.19483
# [23]	validation_0-rmse:1.9102	validation_1-rmse:2.17266
# [24]	validation_0-rmse:1.86086	validation_1-rmse:2.15625
# [25]	validation_0-rmse:1.81729	validation_1-rmse:2.14479
# [26]	validation_0-rmse:1.77705	validation_1-rmse:2.1292
# [27]	validation_0-rmse:1.74067	validation_1-rmse:2.12254
# [28]	validation_0-rmse:1.70844	validation_1-rmse:2.11255
# [29]	validation_0-rmse:1.67617	validation_1-rmse:2.10305
# [30]	validation_0-rmse:1.64899	validation_1-rmse:2.08988
# [31]	validation_0-rmse:1.62712	validation_1-rmse:2.08176
# [32]	validation_0-rmse:1.60699	validation_1-rmse:2.07909
# [33]	validation_0-rmse:1.58734	validation_1-rmse:2.07547
# [34]	validation_0-rmse:1.56985	validation_1-rmse:2.07401
# [35]	validation_0-rmse:1.55473	validation_1-rmse:2.0703
# [36]	validation_0-rmse:1.53997	validation_1-rmse:2.06706
# [37]	validation_0-rmse:1.52705	validation_1-rmse:2.06448
# [38]	validation_0-rmse:1.51645	validation_1-rmse:2.06467
# [39]	validation_0-rmse:1.50611	validation_1-rmse:2.06543
# [40]	validation_0-rmse:1.49683	validation_1-rmse:2.06764
# [41]	validation_0-rmse:1.48913	validation_1-rmse:2.06938
# [42]	validation_0-rmse:1.48121	validation_1-rmse:2.06654
# [43]	validation_0-rmse:1.47139	validation_1-rmse:2.06305
# [44]	validation_0-rmse:1.46412	validation_1-rmse:2.0613
# [45]	validation_0-rmse:1.45993	validation_1-rmse:2.06301
# [46]	validation_0-rmse:1.45452	validation_1-rmse:2.06182
# [47]	validation_0-rmse:1.44927	validation_1-rmse:2.06422
# [48]	validation_0-rmse:1.4443	validation_1-rmse:2.07043
# [49]	validation_0-rmse:1.44014	validation_1-rmse:2.07395
# [50]	validation_0-rmse:1.43447	validation_1-rmse:2.07554
# [51]	validation_0-rmse:1.431	validation_1-rmse:2.07715
# [52]	validation_0-rmse:1.42788	validation_1-rmse:2.07934
# [53]	validation_0-rmse:1.42482	validation_1-rmse:2.08246
# [54]	validation_0-rmse:1.42263	validation_1-rmse:2.08513
# [55]	validation_0-rmse:1.42031	validation_1-rmse:2.08443
# [56]	validation_0-rmse:1.41818	validation_1-rmse:2.08376
# [57]	validation_0-rmse:1.41652	validation_1-rmse:2.08616
# [58]	validation_0-rmse:1.41473	validation_1-rmse:2.08752
# [59]	validation_0-rmse:1.41295	validation_1-rmse:2.08661
# [60]	validation_0-rmse:1.41169	validation_1-rmse:2.08834
# [61]	validation_0-rmse:1.41043	validation_1-rmse:2.08749
# [62]	validation_0-rmse:1.40932	validation_1-rmse:2.08969
# [63]	validation_0-rmse:1.40787	validation_1-rmse:2.0895
# [64]	validation_0-rmse:1.40676	validation_1-rmse:2.09236
# Stopping. Best iteration:
# [44]	validation_0-rmse:1.46412	validation_1-rmse:2.0613
#
# Best hyperparameters: {'max_depth': 15, 'n_estimators': 1000}

# %%
# les meilleurs hyperparametres
print("Best hyperparameters:", grid_search.best_params_)
# Out:
# Best hyperparameters: {'max_depth': 15, 'n_estimators': 1000}

# %%
# Prédiction et Evaluation du meilleur modèle
Y_XGB_valid_pred_opt = grid_search.predict(X_XGB_valid)
Y_XGB_train_pred_opt = grid_search.predict(X_XGB_train)

# Métriques d'evaluation
get_all_performances(value_train=(Y_XGB_train, Y_XGB_train_pred_opt),
                     values_test=(Y_XGB_valid, Y_XGB_valid_pred_opt),
                     metrics=METRICS)
# Out:
#                            metric       train        test
# 0                        r2_score    0.964909    0.871858
# 1              mean_squared_error    2.147358    4.248999
# 2  mean_absolute_percentage_error    0.440065    0.469331
# 3                       max_error  114.889038  107.637512

# %%
# graphique de comparaison entre train et test
sns.set()
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
sns.scatterplot(x = Y_XGB_valid, y = Y_XGB_valid_pred_opt, alpha = 0.6, ax = axs[0])
sns.lineplot(Y_XGB_valid, Y_XGB_valid, ax = axs[0])
axs[0].set_xlabel(" ventes effectives ")
axs[0].set_ylabel("ventes prédites")
axs[0].set_title(" vrais ventes vs ventes prédites (test)")
sns.scatterplot(x = Y_XGB_train, y = Y_XGB_train_pred_opt, alpha = 0.6, ax = axs[1])
sns.lineplot(Y_XGB_train, Y_XGB_train, ax = axs[1])
axs[1].set_xlabel(" ventes effectives ")
axs[1].set_ylabel("ventes prédites")
axs[1].set_title(" vrais ventes vs ventes prédites (train)")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
del X_XGB_train,Y_XGB_train , X_XGB_valid , Y_XGB_valid , model
